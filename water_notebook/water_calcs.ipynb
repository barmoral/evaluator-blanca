# %% [markdown]
# # Core Imports and Setup

# %%
import os
from pathlib import Path

import warnings
warnings.filterwarnings("ignore")

import logging
logging.getLogger("openff.toolkit").setLevel(logging.ERROR)

from openff import toolkit, evaluator
# Out:
# LICENSE: Could not open license file "oe_license.txt" in local directory
# LICENSE: N.B. OE_LICENSE environment variable is not set
# LICENSE: N.B. OE_DIR environment variable is not set
# LICENSE: No product keys!
# LICENSE: No product keys!
# LICENSE: No product keys!
# LICENSE: No product keys!

# %% [markdown]
# # 0) Registering Custom ThermoML Properties

# %%
from openff.units import unit
from openff.evaluator import properties
from openff.evaluator.datasets.thermoml import thermoml_property
from openff.evaluator.datasets import PhysicalProperty, PropertyPhase

@thermoml_property("Osmotic coefficient", supported_phases=PropertyPhase.Liquid)
class OsmoticCoefficient(PhysicalProperty):
    """A class representation of a osmotic coeff property"""

    @classmethod
    def default_unit(cls):
        return unit.dimensionless

custom_thermoml_props = [
    OsmoticCoefficient,
]

for custom_prop_cls in custom_thermoml_props:    
    setattr(properties, custom_prop_cls.__name__, custom_prop_cls)

# %% [markdown]
# # 2) Estimating Data Sets

# %% [markdown]
# ## Loading data set and FF parameters

# %%
import logging
from collections import defaultdict
from enum import Enum
from os import path

import numpy as np
from openff.units import unit
from openmm import app

from openff.evaluator.forcefield import SmirnoffForceFieldSource
from openff.evaluator.attributes import UNDEFINED
from openff.evaluator.substances import Component, ExactAmount, MoleFraction, Substance
from openff.evaluator.utils import packmol
from openff.evaluator.workflow import Protocol, workflow_protocol
from openff.evaluator.workflow.attributes import InputAttribute, OutputAttribute
from openff.evaluator.protocols import coordinates, forcefield
from openff.evaluator.workflow import utils
from openff.evaluator.workflow import Workflow

# %%
force_field_path = "openff-1.0.0.offxml"
force_field_source = SmirnoffForceFieldSource.from_path(force_field_path)

# Define a protocol which will build some coordinates for a system.
build_coordinates = coordinates.BuildCoordinatesPackmol("build_coordinates")
build_coordinates.max_molecules = 1000
build_coordinates.mass_density = 1.0 * unit.gram / unit.millilitre
build_coordinates.substance = Substance.from_components("O", "CO")
build_coordinates.substance = utils.ProtocolPath("substance", "global")

# Define a protocol which will assign force field parameters to the system.
assign_parameters = forcefield.BuildSmirnoffSystem(f"assign_parameters")
assign_parameters.water_model = forcefield.TemplateBuildSystem.WaterModel.TIP3P
assign_parameters.force_field_path = "openff-1.0.0.offxml"

# Set the `coordinate_file_path` input of the `assign_parameters` protocol
# to the `coordinate_file_path` output of the `build_coordinates` protocol.
assign_parameters.coordinate_file_path = utils.ProtocolPath(
    "coordinate_file_path", build_coordinates.id
)

substances = [
    Substance.from_components("CO"),
    Substance.from_components("O"),
]

# %% [markdown]
# ## Defining Calculation Schemas

# %%
from openff.evaluator.properties import Density,EnthalpyOfMixing
from openff.evaluator.client import RequestOptions


h_mix_schema = EnthalpyOfMixing.default_simulation_schema()
h_mix_schema.workflow_schema.final_value_source=utils.ProtocolPath("result", h_mix_schema)
h_mix_schema.workflow_schema.protocol_schemas = [build_coordinates.schema, assign_parameters.schema]

for substance in substances:
    # Define the metadata to make available to the workflow protocols.
    metadata = {"substance": substance}
    # Create the executable workflow object from its schema.
    h_mix_workflow = Workflow.from_schema(h_mix_schema.workflow_schema, metadata=metadata)

# # Create an options object which defines how the data set should be estimated.
# estimation_options = RequestOptions()

# # Specify that we only wish to use molecular simulation to estimate the data set.
# estimation_options.calculation_layers = ["SimulationLayer"]

# # Add our custom schemas, specifying that the should be used by the 'SimulationLayer'
# estimation_options.add_schema("SimulationLayer", "EnthalpyOfMixing", h_mix_schema)

# Add the individual protocol's schema representations to the workflow schema.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       2 from openff.evaluator.client import RequestOptions
#       5 h_mix_schema = EnthalpyOfMixing.default_simulation_schema()
# ----> 6 h_mix_schema.workflow_schema.final_value_source=utils.ProtocolPath("result", h_mix_schema)
#       7 h_mix_schema.workflow_schema.protocol_schemas = [build_coordinates.schema, assign_parameters.schema]
#       9 for substance in substances:
#      10     # Define the metadata to make available to the workflow protocols.
#
# File ~/miniforge3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/workflow/utils.py:95, in ProtocolPath.__init__(self, property_name, *protocol_ids)
#      92 self._protocol_path = None
#      93 self._full_path = None
# ---> 95 self._update_string_paths()
#
# File ~/miniforge3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/workflow/utils.py:105, in ProtocolPath._update_string_paths(self)
#     102 self._protocol_path = ""
#     104 if len(self._protocol_ids) > 0:
# --> 105     self._protocol_path = ProtocolPath.path_separator.join(self._protocol_ids)
#     107 property_name = "" if self._property_name is None else self._property_name
#     109 self._full_path = (
#     110     f"{self._protocol_path}{ProtocolPath.property_separator}{property_name}"
#     111 )
#
# TypeError: sequence item 0: expected str instance, SimulationSchema found

# %% [markdown]
# ## Launching a Server and Client

# %%
from openff.evaluator.backends import ComputeResources
from openff.evaluator.backends.dask import DaskLocalCluster
from openff.evaluator.server import EvaluatorServer
from openff.evaluator.client import EvaluatorClient
from openff.evaluator.client import ConnectionOptions

# define client to submit queries
port = 8117
evaluator_client = EvaluatorClient(ConnectionOptions(server_port=port))

# define available / preferred resources
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
resources = ComputeResources(
    number_of_threads=1,
    number_of_gpus=1,
    preferred_gpu_toolkit=ComputeResources.GPUToolkit.CUDA,
)

with DaskLocalCluster(number_of_workers=1, resources_per_worker=resources) as calculation_backend:
    # spin up server
    evaluator_server = EvaluatorServer(calculation_backend=calculation_backend, delete_working_files=False, port=port)
    evaluator_server.start(asynchronous=True)

    # estimate data set by submitting calculation schemas to newly-created server
    request, exception = evaluator_client.request_estimate(
        property_set=data_set,
        force_field_source=force_field_source,
        options=estimation_options,
    )

    # Wait for the results.
    results, exception = request.results(synchronous=True, polling_interval=30)
    assert exception is None
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 25
#      22 evaluator_server.start(asynchronous=True)
#      24 # estimate data set by submitting calculation schemas to newly-created server
# ---> 25 request, exception = evaluator_client.request_estimate(
#      26     property_set=data_set,
#      27     force_field_source=force_field_source,
#      28     options=estimation_options,
#      29 )
#      31 # Wait for the results.
#      32 results, exception = request.results(synchronous=True, polling_interval=30)
#
# File ~/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/client/client.py:664, in EvaluatorClient.request_estimate(self, property_set, force_field_source, options, parameter_gradient_keys)
#     661 from openff.toolkit.typing.engines import smirnoff
#     663 if property_set is None or force_field_source is None:
# --> 664     raise ValueError(
#     665         "Both a data set and force field source must be "
#     666         "present to compute physical properties."
#     667     )
#     669 if parameter_gradient_keys is None:
#     670     parameter_gradient_keys = []
#
# ValueError: Both a data set and force field source must be present to compute physical properties.

# %%
a = results.estimated_properties.json("estimated_data_set.json", format=True)

# %%
print(a)
# Out:
# {
#   "@type": "openff.evaluator.datasets.datasets.PhysicalPropertyDataSet",
#   "properties": [
#     {
#       "@type": "openff.evaluator.properties.density.Density",
#       "gradients": [],
#       "id": "773858b70c18451e817c70f611f8cd79",
#       "phase": 2,
#       "source": {
#         "@type": "openff.evaluator.datasets.provenance.CalculationSource",
#         "fidelity": "SimulationLayer",
#         "provenance": "{\"protocol_schemas\": [{\"id\": \"773858b70c18451e817c70f611f8cd79|decorrelate_trajectory\", \"type\": \"DecorrelateTrajectory\", \"inputs\": {\".allow_merging\": true, \".time_series_statistics\": {\"full_path\": \"b749b50ecaae494394be40d2aaf9cef9|conditional_group/773858b70c18451e817c70f611f8cd79|average_density.time_series_statistics\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_coordinate_file\": {\"full_path\": \"b749b50ecaae494394be40d2aaf9cef9|conditional_group/b749b50ecaae494394be40d2aaf9cef9|production_simulation_liquid.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_trajectory_path\": {\"full_path\": \"b749b50ecaae494394be40d2aaf9cef9|conditional_group/b749b50ecaae494394be40d2aaf9cef9|production_simulation_liquid.trajectory_file_path\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"773858b70c18451e817c70f611f8cd79|decorrelate_observables\", \"type\": \"DecorrelateObservables\", \"inputs\": {\".allow_merging\": true, \".time_series_statistics\": {\"full_path\": \"b749b50ecaae494394be40d2aaf9cef9|conditional_group/773858b70c18451e817c70f611f8cd79|average_density.time_series_statistics\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_observables\": {\"full_path\": \"b749b50ecaae494394be40d2aaf9cef9|conditional_group/b749b50ecaae494394be40d2aaf9cef9|production_simulation_liquid.observables\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"b749b50ecaae494394be40d2aaf9cef9|build_coordinates_liquid\", \"type\": \"BuildCoordinatesPackmol\", \"inputs\": {\".allow_merging\": true, \".max_molecules\": 256, \".count_exact_amount\": true, \".mass_density\": {\"value\": 0.95, \"unit\": \"gram / milliliter\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".box_aspect_ratio\": [1.0, 1.0, 1.0], \".substance\": {\"components\": [{\"smiles\": \"CC(C)O\", \"role\": {\"value\": \"solv\", \"@type\": \"openff.evaluator.substances.components.Component.Role\"}, \"@type\": \"openff.evaluator.substances.components.Component\"}], \"amounts\": {\"CC(C)O{solv}\": [{\"value\": 1.0, \"@type\": \"openff.evaluator.substances.amounts.MoleFraction\"}]}, \"@type\": \"openff.evaluator.substances.substances.Substance\"}, \".tolerance\": {\"value\": 2.0, \"unit\": \"angstrom\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".verbose_packmol\": false, \".retain_packmol_files\": false}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"b749b50ecaae494394be40d2aaf9cef9|assign_parameters_liquid\", \"type\": \"BuildSmirnoffSystem\", \"inputs\": {\".allow_merging\": true, \".force_field_path\": \"working-data/SimulationLayer/bd4be856e3554455a799e1f0489d4a3a/dca83728f20c417ea1a80ae6b2a17913\", \".coordinate_file_path\": {\"full_path\": \"b749b50ecaae494394be40d2aaf9cef9|build_coordinates_liquid.coordinate_file_path\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".substance\": {\"full_path\": \"b749b50ecaae494394be40d2aaf9cef9|build_coordinates_liquid.output_substance\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"b749b50ecaae494394be40d2aaf9cef9|energy_minimisation_liquid\", \"type\": \"OpenMMEnergyMinimisation\", \"inputs\": {\".allow_merging\": true, \".input_coordinate_file\": {\"full_path\": \"b749b50ecaae494394be40d2aaf9cef9|build_coordinates_liquid.coordinate_file_path\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"b749b50ecaae494394be40d2aaf9cef9|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".tolerance\": {\"value\": 10.0, \"unit\": \"kilojoules_per_mole / nanometer\", \"@type ...
#       },
#       "substance": {
#         "@type": "openff.evaluator.substances.substances.Substance",
#         "amounts": {
#           "CC(C)O{solv}": [
#             {
#               "@type": "openff.evaluator.substances.amounts.MoleFraction",
#               "value": 1.0
#             }
#           ]
#         },
#         "components": [
#           {
#             "@type": "openff.evaluator.substances.components.Component",
#             "role": {
#               "@type": "openff.evaluator.substances.components.Component.Role",
#               "value": "solv"
#             },
#             "smiles": "CC(C)O"
#           }
#         ]
#       },
#       "thermodynamic_state": {
#         "@type": "openff.evaluator.thermodynamics.ThermodynamicState",
#         "pressure": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kilopascal",
#           "value": 101.325
#         },
#         "temperature": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kelvin",
#           "value": 298.15
#         }
#       },
#       "uncertainty": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "gram / milliliter",
#         "value": 0.0008849679977855863
#       },
#       "value": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "gram / milliliter",
#         "value": 0.8040697148239351
#       }
#     },
#     {
#       "@type": "openff.evaluator.properties.enthalpy.EnthalpyOfVaporization",
#       "gradients": [],
#       "id": "b749b50ecaae494394be40d2aaf9cef9",
#       "phase": 6,
#       "source": {
#         "@type": "openff.evaluator.datasets.provenance.CalculationSource",
#         "fidelity": "SimulationLayer",
#         "provenance": "{\"protocol_schemas\": [{\"id\": \"b749b50ecaae494394be40d2aaf9cef9|build_coordinates_liquid\", \"type\": \"BuildCoordinatesPackmol\", \"inputs\": {\".allow_merging\": true, \".max_molecules\": 256, \".count_exact_amount\": true, \".mass_density\": {\"value\": 0.95, \"unit\": \"gram / milliliter\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".box_aspect_ratio\": [1.0, 1.0, 1.0], \".substance\": {\"components\": [{\"smiles\": \"CC(C)O\", \"role\": {\"value\": \"solv\", \"@type\": \"openff.evaluator.substances.components.Component.Role\"}, \"@type\": \"openff.evaluator.substances.components.Component\"}], \"amounts\": {\"CC(C)O{solv}\": [{\"value\": 1.0, \"@type\": \"openff.evaluator.substances.amounts.MoleFraction\"}]}, \"@type\": \"openff.evaluator.substances.substances.Substance\"}, \".tolerance\": {\"value\": 2.0, \"unit\": \"angstrom\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".verbose_packmol\": false, \".retain_packmol_files\": false}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"b749b50ecaae494394be40d2aaf9cef9|energy_minimisation_liquid\", \"type\": \"OpenMMEnergyMinimisation\", \"inputs\": {\".allow_merging\": true, \".input_coordinate_file\": {\"full_path\": \"b749b50ecaae494394be40d2aaf9cef9|build_coordinates_liquid.coordinate_file_path\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"b749b50ecaae494394be40d2aaf9cef9|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".tolerance\": {\"value\": 10.0, \"unit\": \"kilojoules_per_mole / nanometer\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".max_iterations\": 0, \".enable_pbc\": true}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"b749b50ecaae494394be40d2aaf9cef9|equilibration_simulation_liquid\", \"type\": \"OpenMMSimulation\", \"inputs\": {\".allow_merging\": true, \".steps_per_iteration\": 100000, \".total_number_of_iterations\": 1, \".output_frequency\": 5000, \".checkpoint_frequency\": 10, \".timestep\": {\"value\": 2.0, \"unit\": \"femtosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".thermodynamic_state\": {\"temperature\": {\"value\": 298.15, \"unit\": \"kelvin\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"pressure\": {\"value\": 1.0, \"unit\": \"standard_atmosphere\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"@type\": \"openff.evaluator.thermodynamics.ThermodynamicState\"}, \".ensemble\": {\"value\": \"NPT\", \"@type\": \"openff.evaluator.thermodynamics.Ensemble\"}, \".thermostat_friction\": {\"value\": 1.0, \"unit\": \"1 / picosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".input_coordinate_file\": {\"full_path\": \"b749b50ecaae494394be40d2aaf9cef9|energy_minimisation_liquid.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"b749b50ecaae494394be40d2aaf9cef9|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".enable_pbc\": true, \".allow_gpu_platforms\": true, \".high_precision\": false, \".gradient_parameters\": []}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"b749b50ecaae494394be40d2aaf9cef9|decorrelate_trajectory_liquid\", \"type\": \"DecorrelateTrajectory\", \"inputs\": {\".allow_merging\": true, \".time_series_statistics\": {\"full_path\": \"b749b50ecaae494394be40d2aaf9cef9|conditional_group/b749b50ecaae494394be40d2aaf9cef9|average_liquid_potential.time_series_statistics\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_coordinate_file\": {\"full_path\": \"b749b50ecaae494394be40d2aaf9cef9|conditional_group/b749b50ecaae494394be40d2aaf9cef9|production_simulation_liquid.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_trajectory_path\": {\"full_path\ ...
#       },
#       "substance": {
#         "@type": "openff.evaluator.substances.substances.Substance",
#         "amounts": {
#           "CC(C)O{solv}": [
#             {
#               "@type": "openff.evaluator.substances.amounts.MoleFraction",
#               "value": 1.0
#             }
#           ]
#         },
#         "components": [
#           {
#             "@type": "openff.evaluator.substances.components.Component",
#             "role": {
#               "@type": "openff.evaluator.substances.components.Component.Role",
#               "value": "solv"
#             },
#             "smiles": "CC(C)O"
#           }
#         ]
#       },
#       "thermodynamic_state": {
#         "@type": "openff.evaluator.thermodynamics.ThermodynamicState",
#         "pressure": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "standard_atmosphere",
#           "value": 1.0
#         },
#         "temperature": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kelvin",
#           "value": 298.15
#         }
#       },
#       "uncertainty": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "kilojoule / mole",
#         "value": 0.16162165069904044
#       },
#       "value": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "kilojoule / mole",
#         "value": 45.793720514342546
#       }
#     },
#     {
#       "@type": "openff.evaluator.properties.density.Density",
#       "gradients": [],
#       "id": "11364b2ab1d6460c9a71efefb0636d73",
#       "phase": 2,
#       "source": {
#         "@type": "openff.evaluator.datasets.provenance.CalculationSource",
#         "fidelity": "SimulationLayer",
#         "provenance": "{\"protocol_schemas\": [{\"id\": \"11364b2ab1d6460c9a71efefb0636d73|decorrelate_trajectory\", \"type\": \"DecorrelateTrajectory\", \"inputs\": {\".allow_merging\": true, \".time_series_statistics\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|conditional_group/11364b2ab1d6460c9a71efefb0636d73|average_density.time_series_statistics\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_coordinate_file\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|conditional_group/37e01e6fe26a4a78b91bda9bdf94bfe4|production_simulation_liquid.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_trajectory_path\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|conditional_group/37e01e6fe26a4a78b91bda9bdf94bfe4|production_simulation_liquid.trajectory_file_path\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"11364b2ab1d6460c9a71efefb0636d73|decorrelate_observables\", \"type\": \"DecorrelateObservables\", \"inputs\": {\".allow_merging\": true, \".time_series_statistics\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|conditional_group/11364b2ab1d6460c9a71efefb0636d73|average_density.time_series_statistics\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_observables\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|conditional_group/37e01e6fe26a4a78b91bda9bdf94bfe4|production_simulation_liquid.observables\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|build_coordinates_liquid\", \"type\": \"BuildCoordinatesPackmol\", \"inputs\": {\".allow_merging\": true, \".max_molecules\": 256, \".count_exact_amount\": true, \".mass_density\": {\"value\": 0.95, \"unit\": \"gram / milliliter\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".box_aspect_ratio\": [1.0, 1.0, 1.0], \".substance\": {\"components\": [{\"smiles\": \"CCO\", \"role\": {\"value\": \"solv\", \"@type\": \"openff.evaluator.substances.components.Component.Role\"}, \"@type\": \"openff.evaluator.substances.components.Component\"}], \"amounts\": {\"CCO{solv}\": [{\"value\": 1.0, \"@type\": \"openff.evaluator.substances.amounts.MoleFraction\"}]}, \"@type\": \"openff.evaluator.substances.substances.Substance\"}, \".tolerance\": {\"value\": 2.0, \"unit\": \"angstrom\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".verbose_packmol\": false, \".retain_packmol_files\": false}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|assign_parameters_liquid\", \"type\": \"BuildSmirnoffSystem\", \"inputs\": {\".allow_merging\": true, \".force_field_path\": \"working-data/SimulationLayer/6b7af3a12ce9440eaa802d34e315695a/dca83728f20c417ea1a80ae6b2a17913\", \".coordinate_file_path\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|build_coordinates_liquid.coordinate_file_path\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".substance\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|build_coordinates_liquid.output_substance\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|energy_minimisation_liquid\", \"type\": \"OpenMMEnergyMinimisation\", \"inputs\": {\".allow_merging\": true, \".input_coordinate_file\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|build_coordinates_liquid.coordinate_file_path\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".tolerance\": {\"value\": 10.0, \"unit\": \"kilojoules_per_mole / nanometer\", \"@type\": \" ...
#       },
#       "substance": {
#         "@type": "openff.evaluator.substances.substances.Substance",
#         "amounts": {
#           "CCO{solv}": [
#             {
#               "@type": "openff.evaluator.substances.amounts.MoleFraction",
#               "value": 1.0
#             }
#           ]
#         },
#         "components": [
#           {
#             "@type": "openff.evaluator.substances.components.Component",
#             "role": {
#               "@type": "openff.evaluator.substances.components.Component.Role",
#               "value": "solv"
#             },
#             "smiles": "CCO"
#           }
#         ]
#       },
#       "thermodynamic_state": {
#         "@type": "openff.evaluator.thermodynamics.ThermodynamicState",
#         "pressure": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kilopascal",
#           "value": 101.325
#         },
#         "temperature": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kelvin",
#           "value": 298.15
#         }
#       },
#       "uncertainty": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "gram / milliliter",
#         "value": 0.00068595428880321
#       },
#       "value": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "gram / milliliter",
#         "value": 0.7924156318282707
#       }
#     },
#     {
#       "@type": "openff.evaluator.properties.density.Density",
#       "gradients": [],
#       "id": "fba4f4405f63435d93c4c62d88ec7a29",
#       "phase": 2,
#       "source": {
#         "@type": "openff.evaluator.datasets.provenance.CalculationSource",
#         "fidelity": "SimulationLayer",
#         "provenance": "{\"protocol_schemas\": [{\"id\": \"fba4f4405f63435d93c4c62d88ec7a29|equilibration_simulation\", \"type\": \"OpenMMSimulation\", \"inputs\": {\".allow_merging\": true, \".steps_per_iteration\": 100000, \".total_number_of_iterations\": 1, \".output_frequency\": 5000, \".checkpoint_frequency\": 10, \".timestep\": {\"value\": 2.0, \"unit\": \"femtosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".thermodynamic_state\": {\"temperature\": {\"value\": 303.15, \"unit\": \"kelvin\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"pressure\": {\"value\": 101.325, \"unit\": \"kilopascal\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"@type\": \"openff.evaluator.thermodynamics.ThermodynamicState\"}, \".ensemble\": {\"value\": \"NPT\", \"@type\": \"openff.evaluator.thermodynamics.Ensemble\"}, \".thermostat_friction\": {\"value\": 1.0, \"unit\": \"1 / picosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".input_coordinate_file\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|energy_minimisation_liquid.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".enable_pbc\": true, \".allow_gpu_platforms\": true, \".high_precision\": false, \".gradient_parameters\": []}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"fba4f4405f63435d93c4c62d88ec7a29|conditional_group\", \"type\": \"ConditionalGroup\", \"inputs\": {\".allow_merging\": true, \".conditions\": [], \".max_iterations\": 100}, \"protocol_schemas\": {\"fba4f4405f63435d93c4c62d88ec7a29|production_simulation\": {\"id\": \"fba4f4405f63435d93c4c62d88ec7a29|production_simulation\", \"type\": \"OpenMMSimulation\", \"inputs\": {\".allow_merging\": true, \".steps_per_iteration\": 1000000, \".total_number_of_iterations\": 1, \".output_frequency\": 2000, \".checkpoint_frequency\": 10, \".timestep\": {\"value\": 2.0, \"unit\": \"femtosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".thermodynamic_state\": {\"temperature\": {\"value\": 303.15, \"unit\": \"kelvin\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"pressure\": {\"value\": 101.325, \"unit\": \"kilopascal\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"@type\": \"openff.evaluator.thermodynamics.ThermodynamicState\"}, \".ensemble\": {\"value\": \"NPT\", \"@type\": \"openff.evaluator.thermodynamics.Ensemble\"}, \".thermostat_friction\": {\"value\": 1.0, \"unit\": \"1 / picosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".input_coordinate_file\": {\"full_path\": \"fba4f4405f63435d93c4c62d88ec7a29|equilibration_simulation.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".enable_pbc\": true, \".allow_gpu_platforms\": true, \".high_precision\": false, \".gradient_parameters\": []}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, \"fba4f4405f63435d93c4c62d88ec7a29|average_density\": {\"id\": \"fba4f4405f63435d93c4c62d88ec7a29|average_density\", \"type\": \"AverageObservable\", \"inputs\": {\".allow_merging\": true, \".bootstrap_iterations\": 250, \".bootstrap_sample_size\": 1.0, \".thermodynamic_state\": {\"temperature\": {\"value\": 303.15, \"unit\": \"kelvin\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"pressure\": {\"value\": 101.325, \"unit\": \"kilopascal\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"@type\": \"openff.evaluator.thermodynamics.ThermodynamicState\"}, \".potential_energies\": {\"full_path\": \"fba4f4405f63435d93c4c62d88ec7a29|production_simulation.observables[PotentialEnergy]\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath ...
#       },
#       "substance": {
#         "@type": "openff.evaluator.substances.substances.Substance",
#         "amounts": {
#           "CCO{solv}": [
#             {
#               "@type": "openff.evaluator.substances.amounts.MoleFraction",
#               "value": 1.0
#             }
#           ]
#         },
#         "components": [
#           {
#             "@type": "openff.evaluator.substances.components.Component",
#             "role": {
#               "@type": "openff.evaluator.substances.components.Component.Role",
#               "value": "solv"
#             },
#             "smiles": "CCO"
#           }
#         ]
#       },
#       "thermodynamic_state": {
#         "@type": "openff.evaluator.thermodynamics.ThermodynamicState",
#         "pressure": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kilopascal",
#           "value": 101.325
#         },
#         "temperature": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kelvin",
#           "value": 303.15
#         }
#       },
#       "uncertainty": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "gram / milliliter",
#         "value": 0.0005888248597283128
#       },
#       "value": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "gram / milliliter",
#         "value": 0.7876414704637976
#       }
#     },
#     {
#       "@type": "openff.evaluator.properties.density.Density",
#       "gradients": [],
#       "id": "0fbc785e72ac4c64b5da3dfec3de3e4c",
#       "phase": 2,
#       "source": {
#         "@type": "openff.evaluator.datasets.provenance.CalculationSource",
#         "fidelity": "SimulationLayer",
#         "provenance": "{\"protocol_schemas\": [{\"id\": \"0fbc785e72ac4c64b5da3dfec3de3e4c|equilibration_simulation\", \"type\": \"OpenMMSimulation\", \"inputs\": {\".allow_merging\": true, \".steps_per_iteration\": 100000, \".total_number_of_iterations\": 1, \".output_frequency\": 5000, \".checkpoint_frequency\": 10, \".timestep\": {\"value\": 2.0, \"unit\": \"femtosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".thermodynamic_state\": {\"temperature\": {\"value\": 313.15, \"unit\": \"kelvin\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"pressure\": {\"value\": 101.325, \"unit\": \"kilopascal\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"@type\": \"openff.evaluator.thermodynamics.ThermodynamicState\"}, \".ensemble\": {\"value\": \"NPT\", \"@type\": \"openff.evaluator.thermodynamics.Ensemble\"}, \".thermostat_friction\": {\"value\": 1.0, \"unit\": \"1 / picosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".input_coordinate_file\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|energy_minimisation_liquid.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".enable_pbc\": true, \".allow_gpu_platforms\": true, \".high_precision\": false, \".gradient_parameters\": []}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"0fbc785e72ac4c64b5da3dfec3de3e4c|conditional_group\", \"type\": \"ConditionalGroup\", \"inputs\": {\".allow_merging\": true, \".conditions\": [], \".max_iterations\": 100}, \"protocol_schemas\": {\"0fbc785e72ac4c64b5da3dfec3de3e4c|production_simulation\": {\"id\": \"0fbc785e72ac4c64b5da3dfec3de3e4c|production_simulation\", \"type\": \"OpenMMSimulation\", \"inputs\": {\".allow_merging\": true, \".steps_per_iteration\": 1000000, \".total_number_of_iterations\": 1, \".output_frequency\": 2000, \".checkpoint_frequency\": 10, \".timestep\": {\"value\": 2.0, \"unit\": \"femtosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".thermodynamic_state\": {\"temperature\": {\"value\": 313.15, \"unit\": \"kelvin\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"pressure\": {\"value\": 101.325, \"unit\": \"kilopascal\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"@type\": \"openff.evaluator.thermodynamics.ThermodynamicState\"}, \".ensemble\": {\"value\": \"NPT\", \"@type\": \"openff.evaluator.thermodynamics.Ensemble\"}, \".thermostat_friction\": {\"value\": 1.0, \"unit\": \"1 / picosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".input_coordinate_file\": {\"full_path\": \"0fbc785e72ac4c64b5da3dfec3de3e4c|equilibration_simulation.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".enable_pbc\": true, \".allow_gpu_platforms\": true, \".high_precision\": false, \".gradient_parameters\": []}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, \"0fbc785e72ac4c64b5da3dfec3de3e4c|average_density\": {\"id\": \"0fbc785e72ac4c64b5da3dfec3de3e4c|average_density\", \"type\": \"AverageObservable\", \"inputs\": {\".allow_merging\": true, \".bootstrap_iterations\": 250, \".bootstrap_sample_size\": 1.0, \".thermodynamic_state\": {\"temperature\": {\"value\": 313.15, \"unit\": \"kelvin\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"pressure\": {\"value\": 101.325, \"unit\": \"kilopascal\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"@type\": \"openff.evaluator.thermodynamics.ThermodynamicState\"}, \".potential_energies\": {\"full_path\": \"0fbc785e72ac4c64b5da3dfec3de3e4c|production_simulation.observables[PotentialEnergy]\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath ...
#       },
#       "substance": {
#         "@type": "openff.evaluator.substances.substances.Substance",
#         "amounts": {
#           "CCO{solv}": [
#             {
#               "@type": "openff.evaluator.substances.amounts.MoleFraction",
#               "value": 1.0
#             }
#           ]
#         },
#         "components": [
#           {
#             "@type": "openff.evaluator.substances.components.Component",
#             "role": {
#               "@type": "openff.evaluator.substances.components.Component.Role",
#               "value": "solv"
#             },
#             "smiles": "CCO"
#           }
#         ]
#       },
#       "thermodynamic_state": {
#         "@type": "openff.evaluator.thermodynamics.ThermodynamicState",
#         "pressure": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kilopascal",
#           "value": 101.325
#         },
#         "temperature": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kelvin",
#           "value": 313.15
#         }
#       },
#       "uncertainty": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "gram / milliliter",
#         "value": 0.0006394780311715782
#       },
#       "value": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "gram / milliliter",
#         "value": 0.775704882706539
#       }
#     },
#     {
#       "@type": "openff.evaluator.properties.enthalpy.EnthalpyOfVaporization",
#       "gradients": [],
#       "id": "37e01e6fe26a4a78b91bda9bdf94bfe4",
#       "phase": 6,
#       "source": {
#         "@type": "openff.evaluator.datasets.provenance.CalculationSource",
#         "fidelity": "SimulationLayer",
#         "provenance": "{\"protocol_schemas\": [{\"id\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|build_coordinates_liquid\", \"type\": \"BuildCoordinatesPackmol\", \"inputs\": {\".allow_merging\": true, \".max_molecules\": 256, \".count_exact_amount\": true, \".mass_density\": {\"value\": 0.95, \"unit\": \"gram / milliliter\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".box_aspect_ratio\": [1.0, 1.0, 1.0], \".substance\": {\"components\": [{\"smiles\": \"CCO\", \"role\": {\"value\": \"solv\", \"@type\": \"openff.evaluator.substances.components.Component.Role\"}, \"@type\": \"openff.evaluator.substances.components.Component\"}], \"amounts\": {\"CCO{solv}\": [{\"value\": 1.0, \"@type\": \"openff.evaluator.substances.amounts.MoleFraction\"}]}, \"@type\": \"openff.evaluator.substances.substances.Substance\"}, \".tolerance\": {\"value\": 2.0, \"unit\": \"angstrom\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".verbose_packmol\": false, \".retain_packmol_files\": false}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|energy_minimisation_liquid\", \"type\": \"OpenMMEnergyMinimisation\", \"inputs\": {\".allow_merging\": true, \".input_coordinate_file\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|build_coordinates_liquid.coordinate_file_path\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".tolerance\": {\"value\": 10.0, \"unit\": \"kilojoules_per_mole / nanometer\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".max_iterations\": 0, \".enable_pbc\": true}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|equilibration_simulation_liquid\", \"type\": \"OpenMMSimulation\", \"inputs\": {\".allow_merging\": true, \".steps_per_iteration\": 100000, \".total_number_of_iterations\": 1, \".output_frequency\": 5000, \".checkpoint_frequency\": 10, \".timestep\": {\"value\": 2.0, \"unit\": \"femtosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".thermodynamic_state\": {\"temperature\": {\"value\": 298.15, \"unit\": \"kelvin\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"pressure\": {\"value\": 1.0, \"unit\": \"standard_atmosphere\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"@type\": \"openff.evaluator.thermodynamics.ThermodynamicState\"}, \".ensemble\": {\"value\": \"NPT\", \"@type\": \"openff.evaluator.thermodynamics.Ensemble\"}, \".thermostat_friction\": {\"value\": 1.0, \"unit\": \"1 / picosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".input_coordinate_file\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|energy_minimisation_liquid.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".enable_pbc\": true, \".allow_gpu_platforms\": true, \".high_precision\": false, \".gradient_parameters\": []}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|decorrelate_trajectory_liquid\", \"type\": \"DecorrelateTrajectory\", \"inputs\": {\".allow_merging\": true, \".time_series_statistics\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|conditional_group/37e01e6fe26a4a78b91bda9bdf94bfe4|average_liquid_potential.time_series_statistics\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_coordinate_file\": {\"full_path\": \"37e01e6fe26a4a78b91bda9bdf94bfe4|conditional_group/37e01e6fe26a4a78b91bda9bdf94bfe4|production_simulation_liquid.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_trajectory_path\": {\"full_path\": \"3 ...
#       },
#       "substance": {
#         "@type": "openff.evaluator.substances.substances.Substance",
#         "amounts": {
#           "CCO{solv}": [
#             {
#               "@type": "openff.evaluator.substances.amounts.MoleFraction",
#               "value": 1.0
#             }
#           ]
#         },
#         "components": [
#           {
#             "@type": "openff.evaluator.substances.components.Component",
#             "role": {
#               "@type": "openff.evaluator.substances.components.Component.Role",
#               "value": "solv"
#             },
#             "smiles": "CCO"
#           }
#         ]
#       },
#       "thermodynamic_state": {
#         "@type": "openff.evaluator.thermodynamics.ThermodynamicState",
#         "pressure": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "standard_atmosphere",
#           "value": 1.0
#         },
#         "temperature": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kelvin",
#           "value": 298.15
#         }
#       },
#       "uncertainty": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "kilojoule / mole",
#         "value": 0.1936266726759634
#       },
#       "value": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "kilojoule / mole",
#         "value": 39.41499762439654
#       }
#     }
#   ]
# }
