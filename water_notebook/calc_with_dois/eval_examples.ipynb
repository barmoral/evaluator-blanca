# %% [markdown]
# # Core Imports and Setup

# %%
import os
from pathlib import Path

import warnings
warnings.filterwarnings("ignore")

import logging
logging.getLogger("openff.toolkit").setLevel(logging.ERROR)

from openff import toolkit, evaluator

from openff.units import unit

# %% [markdown]
# # 0) Registering Custom ThermoML Properties

# %%
from openff.evaluator import properties
from openff.evaluator.datasets.thermoml import thermoml_property
from openff.evaluator.datasets import PhysicalProperty, PropertyPhase

@thermoml_property("Osmotic coefficient", supported_phases=PropertyPhase.Liquid)
class OsmoticCoefficient(PhysicalProperty):
    """A class representation of a osmotic coeff property"""

    @classmethod
    def default_unit(cls):
        return unit.dimensionless
    
...

custom_thermoml_props = [
    OsmoticCoefficient,
]

for custom_prop_cls in custom_thermoml_props:    
    setattr(properties, custom_prop_cls.__name__, custom_prop_cls)

# %% [markdown]
# # 1) - Loading ThermoML Data Sets

# %% [markdown]
# ## Extracting data from ThermoML

# %%
from openff.evaluator.datasets import PhysicalProperty, PropertyPhase, PhysicalPropertyDataSet
from openff.evaluator.datasets.thermoml import thermoml_property, ThermoMLDataSet

data_set_initial = PhysicalPropertyDataSet.from_json("training-properties-with-water.json")
data_set_initial.to_pandas()
# Out:
#        Id  Temperature (K)  Pressure (kPa)   Phase  N Components Component 1  \
# 0    6385           298.15           101.0  Liquid             2   CN1CCCCC1
# 1    6386           298.15           101.0  Liquid             2   CN1CCCCC1
# 2    6387           298.15           101.0  Liquid             2   CN1CCCCC1
# 3    6388           298.15           101.3  Liquid             2    CN(C)CCO
# 4    6389           298.15           101.3  Liquid             2    CN(C)CCO
# ..    ...              ...             ...     ...           ...         ...
# 118  7294           298.15           101.0  Liquid             2    C1COCCN1
# 119  7295           298.15           101.0  Liquid             2    C1COCCN1
# 120  7344           303.15           100.0  Liquid             2   NCCCNCCCN
# 121  7345           303.15           100.0  Liquid             2   NCCCNCCCN
# 122  7346           303.15           100.0  Liquid             2   NCCCNCCCN
#
#       Role 1  Mole Fraction 1 Exact Amount 1 Component 2   Role 2  \
# 0    Solvent          0.24520           None           O  Solvent
# 1    Solvent          0.50500           None           O  Solvent
# 2    Solvent          0.79070           None           O  Solvent
# 3    Solvent          0.26433           None           O  Solvent
# 4    Solvent          0.50770           None           O  Solvent
# ..       ...              ...            ...         ...      ...
# 118  Solvent          0.49110           None           O  Solvent
# 119  Solvent          0.71490           None           O  Solvent
# 120  Solvent          0.30050           None           O  Solvent
# 121  Solvent          0.49980           None           O  Solvent
# 122  Solvent          0.80150           None           O  Solvent
#
#      Mole Fraction 2 Exact Amount 2  EnthalpyOfMixing Value (kJ / mol)  \
# 0            0.75480           None                                NaN
# 1            0.49500           None                                NaN
# 2            0.20930           None                                NaN
# 3            0.73567           None                                NaN
# 4            0.49230           None                                NaN
# ..               ...            ...                                ...
# 118          0.50890           None                             -3.131
# 119          0.28510           None                             -1.753
# 120          0.69950           None                             -6.588
# 121          0.50020           None                             -5.544
# 122          0.19850           None                             -2.233
#
#      EnthalpyOfMixing Uncertainty (kJ / mol)  Density Value (g / ml)  \
# 0                                        NaN                0.903811
# 1                                        NaN                0.858158
# 2                                        NaN                0.826047
# 3                                        NaN                0.959000
# 4                                        NaN                0.923722
# ..                                       ...                     ...
# 118                                      NaN                     NaN
# 119                                      NaN                     NaN
# 120                                      NaN                     NaN
# 121                                      NaN                     NaN
# 122                                      NaN                     NaN
#
#      Density Uncertainty (g / ml)                       Source
# 0                             NaN  10.1016/j.fluid.2010.05.001
# 1                             NaN  10.1016/j.fluid.2010.05.001
# 2                             NaN  10.1016/j.fluid.2010.05.001
# 3                             NaN     10.1021/acs.jced.6b00888
# 4                             NaN    10.1016/j.jct.2004.11.016
# ..                            ...                          ...
# 118                           NaN    10.1016/j.jct.2015.06.006
# 119                           NaN    10.1016/j.jct.2015.06.006
# 120                           NaN    10.1016/j.jct.2015.04.030
# 121                           NaN    10.1016/j.jct.2015.04.030
# 122                           NaN    10.1016/j.jct.2015.04.030
#
# [123 rows x 18 columns]

# %%
print(len(data_set_initial))
print(data_set_initial.property_types)
print(data_set_initial.substances)
# Out:
# 123
# {'EnthalpyOfMixing', 'Density'}
# {<Substance CN1CCNCC1{solv}{x=0.209100}|O{solv}{x=0.790900}>, <Substance C1CCNCC1{solv}{x=0.500000}|O{solv}{x=0.500000}>, <Substance OCCNCCO{solv}{x=0.742100}|O{solv}{x=0.257900}>, <Substance C1COCCN1{solv}{x=0.793000}|O{solv}{x=0.207000}>, <Substance CC(C)O{solv}{x=0.504800}|O{solv}{x=0.495200}>, <Substance CN1CCNCC1{solv}{x=0.510900}|O{solv}{x=0.489100}>, <Substance CN1CCCCC1{solv}{x=0.505000}|O{solv}{x=0.495000}>, <Substance OC1=NCCC1{solv}{x=0.231900}|O{solv}{x=0.768100}>, <Substance NCCNCCO{solv}{x=0.070000}|O{solv}{x=0.930000}>, <Substance Cc1cccnc1{solv}{x=0.700000}|O{solv}{x=0.300000}>, <Substance CN1CCNCC1{solv}{x=0.792600}|O{solv}{x=0.207400}>, <Substance NCCNCCO{solv}{x=0.399700}|O{solv}{x=0.600300}>, <Substance OCCNCCO{solv}{x=0.700042}|O{solv}{x=0.299958}>, <Substance C1CCNCC1{solv}{x=0.250000}|O{solv}{x=0.750000}>, <Substance NCCNCCN{solv}{x=0.241600}|O{solv}{x=0.758400}>, <Substance CN(CCO)CCO{solv}{x=0.494100}|O{solv}{x=0.505900}>, <Substance OC1=NCCC1{solv}{x=0.500000}|O{solv}{x=0.500000}>, <Substance OCCN(CCO)CCO{solv}{x=0.710000}|O{solv}{x=0.290000}>, <Substance CC(C)O{solv}{x=0.764357}|O{solv}{x=0.235643}>, <Substance OCCNCCO{solv}{x=0.285600}|O{solv}{x=0.714400}>, <Substance CN(CCO)CCO{solv}{x=0.259300}|O{solv}{x=0.740700}>, <Substance OCCN(CCO)CCO{solv}{x=0.206300}|O{solv}{x=0.793700}>, <Substance Cn1ccnc1{solv}{x=0.216700}|O{solv}{x=0.783300}>, <Substance OCCN1CCOCC1{solv}{x=0.485200}|O{solv}{x=0.514800}>, <Substance CN(C)CCO{solv}{x=0.264330}|O{solv}{x=0.735670}>, <Substance CN(C)CCCO{solv}{x=0.501300}|O{solv}{x=0.498700}>, <Substance CCN(CC)CCO{solv}{x=0.700300}|O{solv}{x=0.299700}>, <Substance OCCN(CCO)CCO{solv}{x=0.107783}|O{solv}{x=0.892217}>, <Substance CNCCO{solv}{x=0.798800}|O{solv}{x=0.201200}>, <Substance CN1CCNCC1{solv}{x=0.550000}|O{solv}{x=0.450000}>, <Substance CN(C)CCO{solv}{x=0.507700}|O{solv}{x=0.492300}>, <Substance NCCNCCN{solv}{x=0.497400}|O{solv}{x=0.502600}>, <Substance CN(CCO)CCO{solv}{x=0.484900}|O{solv}{x=0.515100}>, <Substance C1CCNCC1{solv}{x=0.750000}|O{solv}{x=0.250000}>, <Substance NCCCNCCCN{solv}{x=0.300500}|O{solv}{x=0.699500}>, <Substance NCCCO{solv}{x=0.272809}|O{solv}{x=0.727191}>, <Substance CN(C)CCO{solv}{x=0.799600}|O{solv}{x=0.200400}>, <Substance OCCOCCO{solv}{x=0.790600}|O{solv}{x=0.209400}>, <Substance NCCNCCN{solv}{x=0.501000}|O{solv}{x=0.499000}>, <Substance Cc1cccnc1{solv}{x=0.225000}|O{solv}{x=0.775000}>, <Substance OCC(O)CO{solv}{x=0.497800}|O{solv}{x=0.502200}>, <Substance NCCNCCN{solv}{x=0.698800}|O{solv}{x=0.301200}>, <Substance OCCNCCO{solv}{x=0.496900}|O{solv}{x=0.503100}>, <Substance CNCCO{solv}{x=0.199200}|O{solv}{x=0.800800}>, <Substance Cn1ccnc1{solv}{x=0.498200}|O{solv}{x=0.501800}>, <Substance C1COCCN1{solv}{x=0.491100}|O{solv}{x=0.508900}>, <Substance CN(C)CCO{solv}{x=0.765200}|O{solv}{x=0.234800}>, <Substance CN1CCOCC1{solv}{x=0.758700}|O{solv}{x=0.241300}>, <Substance OCCOCCO{solv}{x=0.500600}|O{solv}{x=0.499400}>, <Substance NCCCO{solv}{x=0.489642}|O{solv}{x=0.510358}>, <Substance CC(C)O{solv}{x=0.203100}|O{solv}{x=0.796900}>, <Substance OC1=NCCC1{solv}{x=0.246800}|O{solv}{x=0.753200}>, <Substance CN1CCCCC1{solv}{x=0.245200}|O{solv}{x=0.754800}>, <Substance CNCCO{solv}{x=0.501700}|O{solv}{x=0.498300}>, <Substance CN(C)CCCO{solv}{x=0.800100}|O{solv}{x=0.199900}>, <Substance NCCCO{solv}{x=0.751500}|O{solv}{x=0.248500}>, <Substance CN1CCNCC1{solv}{x=0.706500}|O{solv}{x=0.293500}>, <Substance CN(C)CCO{solv}{x=0.536500}|O{solv}{x=0.463500}>, <Substance OCCOCCO{solv}{x=0.700300}|O{solv}{x=0.299700}>, <Substance OCCN(CCO)CCO{solv}{x=0.490200}|O{solv}{x=0.509800}>, <Substance CNCCO{solv}{x=0.198700}|O{solv}{x=0.801300}>, <Substance OCCN1CCOCC1{solv}{x=0.743900}|O{solv}{x=0.256100}>, <Substance C1COCCN1{solv}{x=0.498000}|O{solv}{x=0.502000}>, <Substance CNCCO{solv}{x=0.504100}|O{solv}{x=0.495900}>, <Substance OCCOCCO{solv}{x=0.501000}|O{solv}{x=0.499000}>, <Substance CCN(CC)CCO{solv}{x=0.500200}|O{solv}{x=0.499800}>, <Substance NCCCO{solv}{x=0.498900}| ...

# %% [markdown]
# ## Filtering data set

# %%
from openff.evaluator.datasets.curation.components.filtering import FilterByPropertyTypes, FilterByPropertyTypesSchema
from openff.evaluator.datasets.curation.components.filtering import FilterByTemperature, FilterByTemperatureSchema
from openff.evaluator.datasets.curation.components.filtering import FilterByPressure, FilterByPressureSchema
from openff.evaluator.datasets.curation.components.filtering import FilterBySmiles, FilterBySmilesSchema

data_set_hmix= FilterByPropertyTypes.apply(
    data_set_initial, FilterByPropertyTypesSchema(property_types=["EnthalpyOfMixing"]))

print(len(data_set_hmix))
# Out:
# 57

# %% [markdown]
# ### Inspecting and saving new properties

# %%
# save for future use
data_set_path = Path('filtered_dataset_hmix.json')
data_set_hmix.json(data_set_path, format=True)

# inspect new properties
pandas_data_set = data_set_hmix.to_pandas()
pandas_data_set.head()
# Out:
#      Id  Temperature (K)  Pressure (kPa)   Phase  N Components Component 1  \
# 0  6391           298.15           101.0  Liquid             2    CN(C)CCO
# 1  6392           298.15           101.0  Liquid             2    CN(C)CCO
# 2  6393           298.15           101.0  Liquid             2    CN(C)CCO
# 3  6395           303.15           100.0  Liquid             2  CCN(CC)CCO
# 4  6396           303.15           100.0  Liquid             2  CCN(CC)CCO
#
#     Role 1  Mole Fraction 1 Exact Amount 1 Component 2   Role 2  \
# 0  Solvent           0.2052           None           O  Solvent
# 1  Solvent           0.5365           None           O  Solvent
# 2  Solvent           0.7996           None           O  Solvent
# 3  Solvent           0.2008           None           O  Solvent
# 4  Solvent           0.5002           None           O  Solvent
#
#    Mole Fraction 2 Exact Amount 2  EnthalpyOfMixing Value (kJ / mol)  \
# 0           0.7948           None                             -2.587
# 1           0.4635           None                             -2.575
# 2           0.2004           None                             -1.247
# 3           0.7992           None                             -2.185
# 4           0.4998           None                             -2.504
#
#   EnthalpyOfMixing Uncertainty (kJ / mol)                     Source
# 0                                    None  10.1016/j.jct.2007.03.010
# 1                                    None  10.1016/j.jct.2007.03.010
# 2                                    None  10.1016/j.jct.2007.03.010
# 3                                    None  10.1016/j.jct.2015.04.030
# 4                                    None  10.1016/j.jct.2015.04.030

# %% [markdown]
# # 2) Estimating Data Sets

# %% [markdown]
# ### Loading data set and FF parameters

# %%
from openff.evaluator.forcefield import SmirnoffForceFieldSource

# load data
data_set_path = Path('filtered_dataset_hmix.json')
data_set = PhysicalPropertyDataSet.from_json(data_set_path)

# load FF
ff_path = "openff-2.0.0.offxml"
force_field_source = SmirnoffForceFieldSource.from_path(ff_path)

# %%
from openff.evaluator.protocols.forcefield import BuildSmirnoffSystem

opc3="forcefields/opc3.offxml"
sage="openff-2.0.0.offxml"

assign_parameters=BuildSmirnoffSystem(f"assign_parameters")
assign_parameters.water_model=opc3
assign_parameters.force_field_path=sage
force_field_source=SmirnoffForceFieldSource.from_object(assign_parameters)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 9
#       7 assign_parameters.water_model=opc3
#       8 assign_parameters.force_field_path=sage
# ----> 9 force_field_source=SmirnoffForceFieldSource.from_object(assign_parameters)
#
# File ~/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/forcefield/forcefield.py:82, in SmirnoffForceFieldSource.from_object(cls, force_field)
#      62 @classmethod
#      63 def from_object(cls, force_field):
#      64     """Creates a new `SmirnoffForceFieldSource` from an existing
#      65     `ForceField` object
#      66
#    (...)
#      79         The created object.
#      80     """
# ---> 82     return cls(force_field.to_string("XML", True))
#
# AttributeError: 'BuildSmirnoffSystem' object has no attribute 'to_string'

# %% [markdown]
# ### Defining Calculation Schemas

# %%
from openff.evaluator.properties import Density, EnthalpyOfMixing
from openff.evaluator.client import RequestOptions

# density_schema = Density.default_simulation_schema(n_molecules=256)
h_mix_schema = EnthalpyOfMixing.default_simulation_schema(n_molecules=100)

# Create an options object which defines how the data set should be estimated.
estimation_options = RequestOptions()

# Specify that we only wish to use molecular simulation to estimate the data set.
estimation_options.calculation_layers = ["SimulationLayer"]

# Add our custom schemas, specifying that the should be used by the 'SimulationLayer'
# estimation_options.add_schema("SimulationLayer", "Density", density_schema)
estimation_options.add_schema("SimulationLayer", "EnthalpyOfMixing", h_mix_schema)

# %% [markdown]
# ## Launching a Server and Client

# %%
from openff.evaluator.backends import ComputeResources
from openff.evaluator.backends.dask import DaskLocalCluster
from openff.evaluator.server import EvaluatorServer
from openff.evaluator.client import EvaluatorClient
from openff.evaluator.client import ConnectionOptions

# define client to submit queries
port = 8119
evaluator_client = EvaluatorClient(ConnectionOptions(server_port=port))

# define available / preferred resources
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
resources = ComputeResources(
    number_of_threads=1,
    number_of_gpus=1,
    preferred_gpu_toolkit=ComputeResources.GPUToolkit.CUDA,
)

with DaskLocalCluster(number_of_workers=1, resources_per_worker=resources) as calculation_backend:
    # spin up server
    evaluator_server = EvaluatorServer(calculation_backend=calculation_backend, delete_working_files=False, port=port)
    evaluator_server.start(asynchronous=True)

    # estimate data set by submitting calculation schemas to newly-created server
    request, exception = evaluator_client.request_estimate(
        property_set=data_set,
        force_field_source=force_field_source,
        options=estimation_options,
    )

    # Wait for the results.
    results, exception = request.results(synchronous=True, polling_interval=30)
    assert exception is None
# Out:
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# 2024-06-28 13:48:36,684 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('_wrapped_function-2ae625675ffe4c1e072718771d1c1648')" coro=<Worker.execute() done, defined at /home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# Error processing layer results for request 50b27d965818481ba1d619b707823785
# Traceback (most recent call last):
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/layers/layers.py", line 221, in _process_results
#     results = list(results_future.result())
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/distributed/client.py", line 322, in result
#     return self.client.sync(self._result, callback_timeout=timeout)
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/distributed/client.py", line 336, in _result
#     raise exception
# concurrent.futures._base.CancelledError: _wrapped_function-52f58341c1531563e6c556261a739f80

# %%
a = results.estimated_properties.json("estimated_dataset_hmix.json", format=True)

# %% [markdown]
# ## Analysing Data Sets

# %% [markdown]
# ### Loading the Data Sets

# %%
experimental_data_set_path = "filtered_dataset_hmix.json"
estimated_data_set_path = "estimated_dataset_hmix.json"

# If you have not yet completed the previous tutorials or do not have the data set files
# available, this tutorial will use copies provided by the framework

if not (
    Path(experimental_data_set_path).exists()
    and Path(estimated_data_set_path).exists()
):
    from openff.evaluator.utils import get_data_filename

    experimental_data_set_path = get_data_filename(
        "tutorials/tutorial01/filtered_data_set.json"
    )
    estimated_data_set_path = get_data_filename(
        "tutorials/tutorial02/estimated_data_set.json"
    )

experimental_data_set = PhysicalPropertyDataSet.from_json(experimental_data_set_path)
estimated_data_set = PhysicalPropertyDataSet.from_json(estimated_data_set_path)
