# %% [markdown]
# # Core Imports and Setup

# %%
import os
from pathlib import Path

import warnings
warnings.filterwarnings("ignore")

import logging
logging.getLogger("openff.toolkit").setLevel(logging.ERROR)

from openff import toolkit, evaluator

# %% [markdown]
# # 0) Registering Custom ThermoML Properties

# %%
from openff.units import unit
from openff.evaluator import properties
from openff.evaluator.datasets.thermoml import thermoml_property
from openff.evaluator.datasets import PhysicalProperty, PropertyPhase

@thermoml_property("Osmotic coefficient", supported_phases=PropertyPhase.Liquid)
class OsmoticCoefficient(PhysicalProperty):
    """A class representation of a osmotic coeff property"""

    @classmethod
    def default_unit(cls):
        return unit.dimensionless
    
...

custom_thermoml_props = [
    OsmoticCoefficient,
]

for custom_prop_cls in custom_thermoml_props:    
    setattr(properties, custom_prop_cls.__name__, custom_prop_cls)

# %% [markdown]
# # 1) - Loading ThermoML Data Sets

# %% [markdown]
# ## Extracting data from ThermoML

# %%
from openff.evaluator.datasets import PhysicalProperty, PropertyPhase
from openff.evaluator.datasets.thermoml import thermoml_property
from openff.units import unit

from openff.evaluator.datasets.thermoml import ThermoMLDataSet

# data_set = ThermoMLDataSet.from_doi(
#     '10.1016/j.jct.2011.03.012',
#     # "10.1016/j.fluid.2013.10.034",
# )
data_set = ThermoMLDataSet.from_doi( # defaults from exaple notebook
    "10.1016/j.fluid.2013.10.034",
    "10.1021/je1013476",
)

# %% [markdown]
# ## Filtering data set

# %%
from openff.evaluator.datasets.curation.components.filtering import FilterByPropertyTypes, FilterByPropertyTypesSchema
from openff.evaluator.datasets.curation.components.filtering import FilterByTemperature, FilterByTemperatureSchema
from openff.evaluator.datasets.curation.components.filtering import FilterByPressure, FilterByPressureSchema
from openff.evaluator.datasets.curation.components.filtering import FilterBySmiles, FilterBySmilesSchema

# Property
data_set = FilterByPropertyTypes.apply(
    data_set, FilterByPropertyTypesSchema(property_types=["Density"])
)

# Temperature
data_set = FilterByTemperature.apply(
    data_set, FilterByTemperatureSchema(minimum_temperature=298.0, maximum_temperature=330.0)
)

# Pressure
data_set = FilterByPressure.apply(
    data_set, FilterByPressureSchema(minimum_pressure=100.0, maximum_pressure=101.426)
)

# Solvent
data_set = FilterBySmiles.apply(
    data_set, FilterBySmilesSchema(smiles_to_include=["CCO", "CC(C)O"])
)

print(len(data_set))
# Out:
# 4

# %%
pandas_data_set = data_set.to_pandas()
pandas_data_set[
    [
        "Temperature (K)",
        "Pressure (kPa)",
        "Component 1",
        "Density Value (g / ml)",
        "Source",
    ]
].head()
# Out:
#    Temperature (K)  Pressure (kPa) Component 1  Density Value (g / ml)  \
# 0           298.15         101.325      CC(C)O                 0.78270
# 1           298.15         101.325         CCO                 0.78507
# 2           303.15         101.325         CCO                 0.78072
# 3           313.15         101.325         CCO                 0.77197
#
#                         Source
# 0  10.1016/j.fluid.2013.10.034
# 1            10.1021/je1013476
# 2            10.1021/je1013476
# 3            10.1021/je1013476

# %% [markdown]
# ## Adding Extra Data

# %% [markdown]
# ### Defining new properties

# %%
from openff.evaluator.datasets import MeasurementSource, PropertyPhase
from openff.evaluator.substances import Substance
from openff.evaluator.thermodynamics import ThermodynamicState
from openff.evaluator.properties import EnthalpyOfVaporization

from openff.units import unit

# define thermo state
thermodynamic_state = ThermodynamicState(
    temperature=298.15 * unit.kelvin, pressure=1.0 * unit.atmosphere
)

# define compounds 
ethanol = Substance.from_components("CCO")
isopropanol = Substance.from_components("CC(C)O")

# define source of measurements
source = MeasurementSource(doi="10.1016/S0021-9614(71)80108-8")

# define measurement values
ethanol_hvap = EnthalpyOfVaporization(
    thermodynamic_state=thermodynamic_state,
    phase=PropertyPhase.Liquid | PropertyPhase.Gas,
    substance=ethanol,
    value=42.26 * unit.kilojoule / unit.mole,
    uncertainty=0.02 * unit.kilojoule / unit.mole,
    source=source,
)
isopropanol_hvap = EnthalpyOfVaporization(
    thermodynamic_state=thermodynamic_state,
    phase=PropertyPhase.Liquid | PropertyPhase.Gas,
    substance=isopropanol,
    value=45.34 * unit.kilojoule / unit.mole,
    uncertainty=0.02 * unit.kilojoule / unit.mole,
    source=source,
)
data_set.add_properties(ethanol_hvap, isopropanol_hvap)

# %% [markdown]
# ### Inspecting and saving new properties

# %%
# save for future use
data_set_path = Path('filtered_data_set.json')
data_set.json(data_set_path, format=True)

# inspect new properties
pandas_data_set = data_set.to_pandas()
pandas_data_set
# Out:
#                                  Id  Temperature (K)  Pressure (kPa)  \
# 0  3d19fb72d46f4b7c8e79a651149c2be8           298.15         101.325
# 1  5887f2269c2444e58ed00ea346aced1b           298.15         101.325
# 2  e7ee86acd7e74ab79b5391b524251b3a           303.15         101.325
# 3  a8371ff39b0e4dc695b90b238bac092c           313.15         101.325
# 4  812af1a0210e412b9bb9e072004904ad           298.15         101.325
# 5  2d038320157d43c28bc32e1fe8ecf092           298.15         101.325
#
#           Phase  N Components Component 1   Role 1  Mole Fraction 1  \
# 0        Liquid             1      CC(C)O  Solvent              1.0
# 1        Liquid             1         CCO  Solvent              1.0
# 2        Liquid             1         CCO  Solvent              1.0
# 3        Liquid             1         CCO  Solvent              1.0
# 4  Liquid + Gas             1         CCO  Solvent              1.0
# 5  Liquid + Gas             1      CC(C)O  Solvent              1.0
#
#   Exact Amount 1  EnthalpyOfVaporization Value (kJ / mol)  \
# 0           None                                      NaN
# 1           None                                      NaN
# 2           None                                      NaN
# 3           None                                      NaN
# 4           None                                    42.26
# 5           None                                    45.34
#
#    EnthalpyOfVaporization Uncertainty (kJ / mol)  Density Value (g / ml)  \
# 0                                            NaN                 0.78270
# 1                                            NaN                 0.78507
# 2                                            NaN                 0.78072
# 3                                            NaN                 0.77197
# 4                                           0.02                     NaN
# 5                                           0.02                     NaN
#
#    Density Uncertainty (g / ml)                         Source
# 0                      0.000075    10.1016/j.fluid.2013.10.034
# 1                      0.000060              10.1021/je1013476
# 2                      0.000060              10.1021/je1013476
# 3                      0.000065              10.1021/je1013476
# 4                           NaN  10.1016/S0021-9614(71)80108-8
# 5                           NaN  10.1016/S0021-9614(71)80108-8

# %% [markdown]
# # 2) Estimating Data Sets

# %% [markdown]
# ## Loading data set and FF parameters

# %%
from openff.evaluator.datasets import PhysicalPropertyDataSet
from openff.evaluator.forcefield import SmirnoffForceFieldSource

# load data
data_set_path = Path('filtered_data_set.json')
data_set = PhysicalPropertyDataSet.from_json(data_set_path)

# load FF
force_field_path = "openff-1.0.0.offxml"
force_field_source = SmirnoffForceFieldSource.from_path(force_field_path)

# %% [markdown]
# ## Defining Calculation Schemas

# %%
from openff.evaluator.properties import Density, EnthalpyOfVaporization
from openff.evaluator.client import RequestOptions

density_schema = Density.default_simulation_schema(n_molecules=256)
h_vap_schema = EnthalpyOfVaporization.default_simulation_schema(n_molecules=256)

# Create an options object which defines how the data set should be estimated.
estimation_options = RequestOptions()

# Specify that we only wish to use molecular simulation to estimate the data set.
estimation_options.calculation_layers = ["SimulationLayer"]

# Add our custom schemas, specifying that the should be used by the 'SimulationLayer'
estimation_options.add_schema("SimulationLayer", "Density", density_schema)
estimation_options.add_schema("SimulationLayer", "EnthalpyOfVaporization", h_vap_schema)

# %% [markdown]
# ## Launching a Server and Client

# %%
from openff.evaluator.backends import ComputeResources
from openff.evaluator.backends.dask import DaskLocalCluster
from openff.evaluator.server import EvaluatorServer
from openff.evaluator.client import EvaluatorClient
from openff.evaluator.client import ConnectionOptions

# define client to submit queries
port = 8118
evaluator_client = EvaluatorClient(ConnectionOptions(server_port=port))

# define available / preferred resources
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
resources = ComputeResources(
    number_of_threads=1,
    number_of_gpus=1,
    preferred_gpu_toolkit=ComputeResources.GPUToolkit.CUDA,
)

with DaskLocalCluster(number_of_workers=1, resources_per_worker=resources) as calculation_backend:
    # spin up server
    evaluator_server = EvaluatorServer(calculation_backend=calculation_backend, delete_working_files=False, port=port)
    evaluator_server.start(asynchronous=True)

    # estimate data set by submitting calculation schemas to newly-created server
    request, exception = evaluator_client.request_estimate(
        property_set=data_set,
        force_field_source=force_field_source,
        options=estimation_options,
    )

    # Wait for the results.
    results, exception = request.results(synchronous=True, polling_interval=30)
    assert exception is None
# Out:
# INFO:distributed.http.proxy:To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# INFO:distributed.scheduler:State start
# INFO:distributed.scheduler:  Scheduler at: inproc://172.21.16.71/29424/1
# INFO:distributed.scheduler:  dashboard at:  http://172.21.16.71:8787/status
# INFO:distributed.scheduler:Registering Worker plugin shuffle
# INFO:distributed.worker:      Start worker at: inproc://172.21.16.71/29424/4
# INFO:distributed.worker:         Listening to:         inproc172.21.16.71
# INFO:distributed.worker:          Worker name:                          0
# INFO:distributed.worker:         dashboard at:         172.21.16.71:41401
# INFO:distributed.worker:Waiting to connect to: inproc://172.21.16.71/29424/1
# INFO:distributed.worker:-------------------------------------------------
# INFO:distributed.worker:              Threads:                          1
# INFO:distributed.worker:               Memory:                  31.00 GiB
# INFO:distributed.worker:      Local Directory: /tmp/dask-scratch-space/worker-_4xdk9q0
# INFO:distributed.worker:-------------------------------------------------
# INFO:distributed.scheduler:Register worker <WorkerState 'inproc://172.21.16.71/29424/4', name: 0, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, inproc://172.21.16.71/29424/4
# INFO:distributed.core:Starting established connection to inproc://172.21.16.71/29424/5
# INFO:distributed.worker:Starting Worker plugin shuffle
# INFO:distributed.worker:        Registered to: inproc://172.21.16.71/29424/1
# INFO:distributed.worker:-------------------------------------------------
# INFO:distributed.core:Starting established connection to inproc://172.21.16.71/29424/1
# INFO:distributed.scheduler:Receive client connection: Client-bcc8cdd0-1d5d-11ef-b2f0-a4bb6da12f27
# INFO:distributed.core:Starting established connection to inproc://172.21.16.71/29424/6
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# Warning: Cannot perform Hydrogen sampling with GPU-Omega: GPU-Omega disabled.
# INFO:distributed.scheduler:Remove client Client-bcc8cdd0-1d5d-11ef-b2f0-a4bb6da12f27
# INFO:distributed.core:Received 'close-stream' from inproc://172.21.16.71/29424/6; closing.
# INFO:distributed.scheduler:Remove client Client-bcc8cdd0-1d5d-11ef-b2f0-a4bb6da12f27
# INFO:distributed.scheduler:Close client connection: Client-bcc8cdd0-1d5d-11ef-b2f0-a4bb6da12f27
# INFO:distributed.worker:Stopping worker at inproc://172.21.16.71/29424/4. Reason: worker-close
# INFO:distributed.core:Received 'close-stream' from inproc://172.21.16.71/29424/5; closing.
# INFO:distributed.scheduler:Remove worker <WorkerState 'inproc://172.21.16.71/29424/4', name: 0, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1716949438.7136455')
# INFO:distributed.scheduler:Lost all workers
# INFO:distributed.core:Connection to inproc://172.21.16.71/29424/1 has been closed.
# INFO:distributed.scheduler:Scheduler closing due to unknown reason...
# INFO:distributed.scheduler:Scheduler closing all comms

# %%
a = results.estimated_properties.json("estimated_data_set.json", format=True)

# %%
print(a)
# Out:
# {
#   "@type": "openff.evaluator.datasets.datasets.PhysicalPropertyDataSet",
#   "properties": [
#     {
#       "@type": "openff.evaluator.properties.density.Density",
#       "gradients": [],
#       "id": "3d19fb72d46f4b7c8e79a651149c2be8",
#       "phase": 2,
#       "source": {
#         "@type": "openff.evaluator.datasets.provenance.CalculationSource",
#         "fidelity": "SimulationLayer",
#         "provenance": "{\"protocol_schemas\": [{\"id\": \"3d19fb72d46f4b7c8e79a651149c2be8|decorrelate_trajectory\", \"type\": \"DecorrelateTrajectory\", \"inputs\": {\".allow_merging\": true, \".time_series_statistics\": {\"full_path\": \"2d038320157d43c28bc32e1fe8ecf092|conditional_group/3d19fb72d46f4b7c8e79a651149c2be8|average_density.time_series_statistics\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_coordinate_file\": {\"full_path\": \"2d038320157d43c28bc32e1fe8ecf092|conditional_group/2d038320157d43c28bc32e1fe8ecf092|production_simulation_liquid.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_trajectory_path\": {\"full_path\": \"2d038320157d43c28bc32e1fe8ecf092|conditional_group/2d038320157d43c28bc32e1fe8ecf092|production_simulation_liquid.trajectory_file_path\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"3d19fb72d46f4b7c8e79a651149c2be8|decorrelate_observables\", \"type\": \"DecorrelateObservables\", \"inputs\": {\".allow_merging\": true, \".time_series_statistics\": {\"full_path\": \"2d038320157d43c28bc32e1fe8ecf092|conditional_group/3d19fb72d46f4b7c8e79a651149c2be8|average_density.time_series_statistics\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_observables\": {\"full_path\": \"2d038320157d43c28bc32e1fe8ecf092|conditional_group/2d038320157d43c28bc32e1fe8ecf092|production_simulation_liquid.observables\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"2d038320157d43c28bc32e1fe8ecf092|build_coordinates_liquid\", \"type\": \"BuildCoordinatesPackmol\", \"inputs\": {\".allow_merging\": true, \".max_molecules\": 256, \".count_exact_amount\": true, \".mass_density\": {\"value\": 0.95, \"unit\": \"gram / milliliter\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".box_aspect_ratio\": [1.0, 1.0, 1.0], \".substance\": {\"components\": [{\"smiles\": \"CC(C)O\", \"role\": {\"value\": \"solv\", \"@type\": \"openff.evaluator.substances.components.Component.Role\"}, \"@type\": \"openff.evaluator.substances.components.Component\"}], \"amounts\": {\"CC(C)O{solv}\": [{\"value\": 1.0, \"@type\": \"openff.evaluator.substances.amounts.MoleFraction\"}]}, \"@type\": \"openff.evaluator.substances.substances.Substance\"}, \".tolerance\": {\"value\": 2.0, \"unit\": \"angstrom\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".verbose_packmol\": false, \".retain_packmol_files\": false}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"2d038320157d43c28bc32e1fe8ecf092|assign_parameters_liquid\", \"type\": \"BuildSmirnoffSystem\", \"inputs\": {\".allow_merging\": true, \".force_field_path\": \"working-data/SimulationLayer/678c6cfe95df47dca65d17d05db6f015/3497a61da0a4491383864939ce1e63de\", \".coordinate_file_path\": {\"full_path\": \"2d038320157d43c28bc32e1fe8ecf092|build_coordinates_liquid.coordinate_file_path\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".substance\": {\"full_path\": \"2d038320157d43c28bc32e1fe8ecf092|build_coordinates_liquid.output_substance\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"2d038320157d43c28bc32e1fe8ecf092|energy_minimisation_liquid\", \"type\": \"OpenMMEnergyMinimisation\", \"inputs\": {\".allow_merging\": true, \".input_coordinate_file\": {\"full_path\": \"2d038320157d43c28bc32e1fe8ecf092|build_coordinates_liquid.coordinate_file_path\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"2d038320157d43c28bc32e1fe8ecf092|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".tolerance\": {\"value\": 10.0, \"unit\": \"kilojoules_per_mole / nanometer\", \"@type ...
#       },
#       "substance": {
#         "@type": "openff.evaluator.substances.substances.Substance",
#         "amounts": {
#           "CC(C)O{solv}": [
#             {
#               "@type": "openff.evaluator.substances.amounts.MoleFraction",
#               "value": 1.0
#             }
#           ]
#         },
#         "components": [
#           {
#             "@type": "openff.evaluator.substances.components.Component",
#             "role": {
#               "@type": "openff.evaluator.substances.components.Component.Role",
#               "value": "solv"
#             },
#             "smiles": "CC(C)O"
#           }
#         ]
#       },
#       "thermodynamic_state": {
#         "@type": "openff.evaluator.thermodynamics.ThermodynamicState",
#         "pressure": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kilopascal",
#           "value": 101.325
#         },
#         "temperature": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kelvin",
#           "value": 298.15
#         }
#       },
#       "uncertainty": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "gram / milliliter",
#         "value": 0.0005296028226146223
#       },
#       "value": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "gram / milliliter",
#         "value": 0.8027545298602813
#       }
#     },
#     {
#       "@type": "openff.evaluator.properties.enthalpy.EnthalpyOfVaporization",
#       "gradients": [],
#       "id": "2d038320157d43c28bc32e1fe8ecf092",
#       "phase": 6,
#       "source": {
#         "@type": "openff.evaluator.datasets.provenance.CalculationSource",
#         "fidelity": "SimulationLayer",
#         "provenance": "{\"protocol_schemas\": [{\"id\": \"2d038320157d43c28bc32e1fe8ecf092|build_coordinates_liquid\", \"type\": \"BuildCoordinatesPackmol\", \"inputs\": {\".allow_merging\": true, \".max_molecules\": 256, \".count_exact_amount\": true, \".mass_density\": {\"value\": 0.95, \"unit\": \"gram / milliliter\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".box_aspect_ratio\": [1.0, 1.0, 1.0], \".substance\": {\"components\": [{\"smiles\": \"CC(C)O\", \"role\": {\"value\": \"solv\", \"@type\": \"openff.evaluator.substances.components.Component.Role\"}, \"@type\": \"openff.evaluator.substances.components.Component\"}], \"amounts\": {\"CC(C)O{solv}\": [{\"value\": 1.0, \"@type\": \"openff.evaluator.substances.amounts.MoleFraction\"}]}, \"@type\": \"openff.evaluator.substances.substances.Substance\"}, \".tolerance\": {\"value\": 2.0, \"unit\": \"angstrom\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".verbose_packmol\": false, \".retain_packmol_files\": false}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"2d038320157d43c28bc32e1fe8ecf092|energy_minimisation_liquid\", \"type\": \"OpenMMEnergyMinimisation\", \"inputs\": {\".allow_merging\": true, \".input_coordinate_file\": {\"full_path\": \"2d038320157d43c28bc32e1fe8ecf092|build_coordinates_liquid.coordinate_file_path\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"2d038320157d43c28bc32e1fe8ecf092|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".tolerance\": {\"value\": 10.0, \"unit\": \"kilojoules_per_mole / nanometer\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".max_iterations\": 0, \".enable_pbc\": true}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"2d038320157d43c28bc32e1fe8ecf092|equilibration_simulation_liquid\", \"type\": \"OpenMMSimulation\", \"inputs\": {\".allow_merging\": true, \".steps_per_iteration\": 100000, \".total_number_of_iterations\": 1, \".output_frequency\": 5000, \".checkpoint_frequency\": 10, \".timestep\": {\"value\": 2.0, \"unit\": \"femtosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".thermodynamic_state\": {\"temperature\": {\"value\": 298.15, \"unit\": \"kelvin\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"pressure\": {\"value\": 1.0, \"unit\": \"standard_atmosphere\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"@type\": \"openff.evaluator.thermodynamics.ThermodynamicState\"}, \".ensemble\": {\"value\": \"NPT\", \"@type\": \"openff.evaluator.thermodynamics.Ensemble\"}, \".thermostat_friction\": {\"value\": 1.0, \"unit\": \"1 / picosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".input_coordinate_file\": {\"full_path\": \"2d038320157d43c28bc32e1fe8ecf092|energy_minimisation_liquid.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"2d038320157d43c28bc32e1fe8ecf092|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".enable_pbc\": true, \".allow_gpu_platforms\": true, \".high_precision\": false, \".gradient_parameters\": []}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"2d038320157d43c28bc32e1fe8ecf092|decorrelate_trajectory_liquid\", \"type\": \"DecorrelateTrajectory\", \"inputs\": {\".allow_merging\": true, \".time_series_statistics\": {\"full_path\": \"2d038320157d43c28bc32e1fe8ecf092|conditional_group/2d038320157d43c28bc32e1fe8ecf092|average_liquid_potential.time_series_statistics\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_coordinate_file\": {\"full_path\": \"2d038320157d43c28bc32e1fe8ecf092|conditional_group/2d038320157d43c28bc32e1fe8ecf092|production_simulation_liquid.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_trajectory_path\": {\"full_path\ ...
#       },
#       "substance": {
#         "@type": "openff.evaluator.substances.substances.Substance",
#         "amounts": {
#           "CC(C)O{solv}": [
#             {
#               "@type": "openff.evaluator.substances.amounts.MoleFraction",
#               "value": 1.0
#             }
#           ]
#         },
#         "components": [
#           {
#             "@type": "openff.evaluator.substances.components.Component",
#             "role": {
#               "@type": "openff.evaluator.substances.components.Component.Role",
#               "value": "solv"
#             },
#             "smiles": "CC(C)O"
#           }
#         ]
#       },
#       "thermodynamic_state": {
#         "@type": "openff.evaluator.thermodynamics.ThermodynamicState",
#         "pressure": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "standard_atmosphere",
#           "value": 1.0
#         },
#         "temperature": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kelvin",
#           "value": 298.15
#         }
#       },
#       "uncertainty": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "kilojoule / mole",
#         "value": 0.21105904473672485
#       },
#       "value": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "kilojoule / mole",
#         "value": 45.51779605077979
#       }
#     },
#     {
#       "@type": "openff.evaluator.properties.density.Density",
#       "gradients": [],
#       "id": "5887f2269c2444e58ed00ea346aced1b",
#       "phase": 2,
#       "source": {
#         "@type": "openff.evaluator.datasets.provenance.CalculationSource",
#         "fidelity": "SimulationLayer",
#         "provenance": "{\"protocol_schemas\": [{\"id\": \"5887f2269c2444e58ed00ea346aced1b|decorrelate_trajectory\", \"type\": \"DecorrelateTrajectory\", \"inputs\": {\".allow_merging\": true, \".time_series_statistics\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|conditional_group/5887f2269c2444e58ed00ea346aced1b|average_density.time_series_statistics\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_coordinate_file\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|conditional_group/812af1a0210e412b9bb9e072004904ad|production_simulation_liquid.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_trajectory_path\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|conditional_group/812af1a0210e412b9bb9e072004904ad|production_simulation_liquid.trajectory_file_path\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"5887f2269c2444e58ed00ea346aced1b|decorrelate_observables\", \"type\": \"DecorrelateObservables\", \"inputs\": {\".allow_merging\": true, \".time_series_statistics\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|conditional_group/5887f2269c2444e58ed00ea346aced1b|average_density.time_series_statistics\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_observables\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|conditional_group/812af1a0210e412b9bb9e072004904ad|production_simulation_liquid.observables\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"812af1a0210e412b9bb9e072004904ad|build_coordinates_liquid\", \"type\": \"BuildCoordinatesPackmol\", \"inputs\": {\".allow_merging\": true, \".max_molecules\": 256, \".count_exact_amount\": true, \".mass_density\": {\"value\": 0.95, \"unit\": \"gram / milliliter\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".box_aspect_ratio\": [1.0, 1.0, 1.0], \".substance\": {\"components\": [{\"smiles\": \"CCO\", \"role\": {\"value\": \"solv\", \"@type\": \"openff.evaluator.substances.components.Component.Role\"}, \"@type\": \"openff.evaluator.substances.components.Component\"}], \"amounts\": {\"CCO{solv}\": [{\"value\": 1.0, \"@type\": \"openff.evaluator.substances.amounts.MoleFraction\"}]}, \"@type\": \"openff.evaluator.substances.substances.Substance\"}, \".tolerance\": {\"value\": 2.0, \"unit\": \"angstrom\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".verbose_packmol\": false, \".retain_packmol_files\": false}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"812af1a0210e412b9bb9e072004904ad|assign_parameters_liquid\", \"type\": \"BuildSmirnoffSystem\", \"inputs\": {\".allow_merging\": true, \".force_field_path\": \"working-data/SimulationLayer/d2dc70b274e34ff4b4841a66de6fdbae/3497a61da0a4491383864939ce1e63de\", \".coordinate_file_path\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|build_coordinates_liquid.coordinate_file_path\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".substance\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|build_coordinates_liquid.output_substance\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"812af1a0210e412b9bb9e072004904ad|energy_minimisation_liquid\", \"type\": \"OpenMMEnergyMinimisation\", \"inputs\": {\".allow_merging\": true, \".input_coordinate_file\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|build_coordinates_liquid.coordinate_file_path\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".tolerance\": {\"value\": 10.0, \"unit\": \"kilojoules_per_mole / nanometer\", \"@type\": \" ...
#       },
#       "substance": {
#         "@type": "openff.evaluator.substances.substances.Substance",
#         "amounts": {
#           "CCO{solv}": [
#             {
#               "@type": "openff.evaluator.substances.amounts.MoleFraction",
#               "value": 1.0
#             }
#           ]
#         },
#         "components": [
#           {
#             "@type": "openff.evaluator.substances.components.Component",
#             "role": {
#               "@type": "openff.evaluator.substances.components.Component.Role",
#               "value": "solv"
#             },
#             "smiles": "CCO"
#           }
#         ]
#       },
#       "thermodynamic_state": {
#         "@type": "openff.evaluator.thermodynamics.ThermodynamicState",
#         "pressure": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kilopascal",
#           "value": 101.325
#         },
#         "temperature": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kelvin",
#           "value": 298.15
#         }
#       },
#       "uncertainty": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "gram / milliliter",
#         "value": 0.0006168381920782527
#       },
#       "value": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "gram / milliliter",
#         "value": 0.7922875232714762
#       }
#     },
#     {
#       "@type": "openff.evaluator.properties.density.Density",
#       "gradients": [],
#       "id": "e7ee86acd7e74ab79b5391b524251b3a",
#       "phase": 2,
#       "source": {
#         "@type": "openff.evaluator.datasets.provenance.CalculationSource",
#         "fidelity": "SimulationLayer",
#         "provenance": "{\"protocol_schemas\": [{\"id\": \"e7ee86acd7e74ab79b5391b524251b3a|equilibration_simulation\", \"type\": \"OpenMMSimulation\", \"inputs\": {\".allow_merging\": true, \".steps_per_iteration\": 100000, \".total_number_of_iterations\": 1, \".output_frequency\": 5000, \".checkpoint_frequency\": 10, \".timestep\": {\"value\": 2.0, \"unit\": \"femtosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".thermodynamic_state\": {\"temperature\": {\"value\": 303.15, \"unit\": \"kelvin\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"pressure\": {\"value\": 101.325, \"unit\": \"kilopascal\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"@type\": \"openff.evaluator.thermodynamics.ThermodynamicState\"}, \".ensemble\": {\"value\": \"NPT\", \"@type\": \"openff.evaluator.thermodynamics.Ensemble\"}, \".thermostat_friction\": {\"value\": 1.0, \"unit\": \"1 / picosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".input_coordinate_file\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|energy_minimisation_liquid.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".enable_pbc\": true, \".allow_gpu_platforms\": true, \".high_precision\": false, \".gradient_parameters\": []}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"e7ee86acd7e74ab79b5391b524251b3a|conditional_group\", \"type\": \"ConditionalGroup\", \"inputs\": {\".allow_merging\": true, \".conditions\": [], \".max_iterations\": 100}, \"protocol_schemas\": {\"e7ee86acd7e74ab79b5391b524251b3a|production_simulation\": {\"id\": \"e7ee86acd7e74ab79b5391b524251b3a|production_simulation\", \"type\": \"OpenMMSimulation\", \"inputs\": {\".allow_merging\": true, \".steps_per_iteration\": 1000000, \".total_number_of_iterations\": 1, \".output_frequency\": 2000, \".checkpoint_frequency\": 10, \".timestep\": {\"value\": 2.0, \"unit\": \"femtosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".thermodynamic_state\": {\"temperature\": {\"value\": 303.15, \"unit\": \"kelvin\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"pressure\": {\"value\": 101.325, \"unit\": \"kilopascal\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"@type\": \"openff.evaluator.thermodynamics.ThermodynamicState\"}, \".ensemble\": {\"value\": \"NPT\", \"@type\": \"openff.evaluator.thermodynamics.Ensemble\"}, \".thermostat_friction\": {\"value\": 1.0, \"unit\": \"1 / picosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".input_coordinate_file\": {\"full_path\": \"e7ee86acd7e74ab79b5391b524251b3a|equilibration_simulation.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".enable_pbc\": true, \".allow_gpu_platforms\": true, \".high_precision\": false, \".gradient_parameters\": []}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, \"e7ee86acd7e74ab79b5391b524251b3a|average_density\": {\"id\": \"e7ee86acd7e74ab79b5391b524251b3a|average_density\", \"type\": \"AverageObservable\", \"inputs\": {\".allow_merging\": true, \".bootstrap_iterations\": 250, \".bootstrap_sample_size\": 1.0, \".thermodynamic_state\": {\"temperature\": {\"value\": 303.15, \"unit\": \"kelvin\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"pressure\": {\"value\": 101.325, \"unit\": \"kilopascal\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"@type\": \"openff.evaluator.thermodynamics.ThermodynamicState\"}, \".potential_energies\": {\"full_path\": \"e7ee86acd7e74ab79b5391b524251b3a|production_simulation.observables[PotentialEnergy]\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath ...
#       },
#       "substance": {
#         "@type": "openff.evaluator.substances.substances.Substance",
#         "amounts": {
#           "CCO{solv}": [
#             {
#               "@type": "openff.evaluator.substances.amounts.MoleFraction",
#               "value": 1.0
#             }
#           ]
#         },
#         "components": [
#           {
#             "@type": "openff.evaluator.substances.components.Component",
#             "role": {
#               "@type": "openff.evaluator.substances.components.Component.Role",
#               "value": "solv"
#             },
#             "smiles": "CCO"
#           }
#         ]
#       },
#       "thermodynamic_state": {
#         "@type": "openff.evaluator.thermodynamics.ThermodynamicState",
#         "pressure": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kilopascal",
#           "value": 101.325
#         },
#         "temperature": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kelvin",
#           "value": 303.15
#         }
#       },
#       "uncertainty": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "gram / milliliter",
#         "value": 0.0006500742238280672
#       },
#       "value": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "gram / milliliter",
#         "value": 0.7875343034230154
#       }
#     },
#     {
#       "@type": "openff.evaluator.properties.density.Density",
#       "gradients": [],
#       "id": "a8371ff39b0e4dc695b90b238bac092c",
#       "phase": 2,
#       "source": {
#         "@type": "openff.evaluator.datasets.provenance.CalculationSource",
#         "fidelity": "SimulationLayer",
#         "provenance": "{\"protocol_schemas\": [{\"id\": \"a8371ff39b0e4dc695b90b238bac092c|equilibration_simulation\", \"type\": \"OpenMMSimulation\", \"inputs\": {\".allow_merging\": true, \".steps_per_iteration\": 100000, \".total_number_of_iterations\": 1, \".output_frequency\": 5000, \".checkpoint_frequency\": 10, \".timestep\": {\"value\": 2.0, \"unit\": \"femtosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".thermodynamic_state\": {\"temperature\": {\"value\": 313.15, \"unit\": \"kelvin\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"pressure\": {\"value\": 101.325, \"unit\": \"kilopascal\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"@type\": \"openff.evaluator.thermodynamics.ThermodynamicState\"}, \".ensemble\": {\"value\": \"NPT\", \"@type\": \"openff.evaluator.thermodynamics.Ensemble\"}, \".thermostat_friction\": {\"value\": 1.0, \"unit\": \"1 / picosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".input_coordinate_file\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|energy_minimisation_liquid.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".enable_pbc\": true, \".allow_gpu_platforms\": true, \".high_precision\": false, \".gradient_parameters\": []}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"a8371ff39b0e4dc695b90b238bac092c|conditional_group\", \"type\": \"ConditionalGroup\", \"inputs\": {\".allow_merging\": true, \".conditions\": [], \".max_iterations\": 100}, \"protocol_schemas\": {\"a8371ff39b0e4dc695b90b238bac092c|production_simulation\": {\"id\": \"a8371ff39b0e4dc695b90b238bac092c|production_simulation\", \"type\": \"OpenMMSimulation\", \"inputs\": {\".allow_merging\": true, \".steps_per_iteration\": 1000000, \".total_number_of_iterations\": 1, \".output_frequency\": 2000, \".checkpoint_frequency\": 10, \".timestep\": {\"value\": 2.0, \"unit\": \"femtosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".thermodynamic_state\": {\"temperature\": {\"value\": 313.15, \"unit\": \"kelvin\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"pressure\": {\"value\": 101.325, \"unit\": \"kilopascal\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"@type\": \"openff.evaluator.thermodynamics.ThermodynamicState\"}, \".ensemble\": {\"value\": \"NPT\", \"@type\": \"openff.evaluator.thermodynamics.Ensemble\"}, \".thermostat_friction\": {\"value\": 1.0, \"unit\": \"1 / picosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".input_coordinate_file\": {\"full_path\": \"a8371ff39b0e4dc695b90b238bac092c|equilibration_simulation.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".enable_pbc\": true, \".allow_gpu_platforms\": true, \".high_precision\": false, \".gradient_parameters\": []}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, \"a8371ff39b0e4dc695b90b238bac092c|average_density\": {\"id\": \"a8371ff39b0e4dc695b90b238bac092c|average_density\", \"type\": \"AverageObservable\", \"inputs\": {\".allow_merging\": true, \".bootstrap_iterations\": 250, \".bootstrap_sample_size\": 1.0, \".thermodynamic_state\": {\"temperature\": {\"value\": 313.15, \"unit\": \"kelvin\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"pressure\": {\"value\": 101.325, \"unit\": \"kilopascal\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"@type\": \"openff.evaluator.thermodynamics.ThermodynamicState\"}, \".potential_energies\": {\"full_path\": \"a8371ff39b0e4dc695b90b238bac092c|production_simulation.observables[PotentialEnergy]\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath ...
#       },
#       "substance": {
#         "@type": "openff.evaluator.substances.substances.Substance",
#         "amounts": {
#           "CCO{solv}": [
#             {
#               "@type": "openff.evaluator.substances.amounts.MoleFraction",
#               "value": 1.0
#             }
#           ]
#         },
#         "components": [
#           {
#             "@type": "openff.evaluator.substances.components.Component",
#             "role": {
#               "@type": "openff.evaluator.substances.components.Component.Role",
#               "value": "solv"
#             },
#             "smiles": "CCO"
#           }
#         ]
#       },
#       "thermodynamic_state": {
#         "@type": "openff.evaluator.thermodynamics.ThermodynamicState",
#         "pressure": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kilopascal",
#           "value": 101.325
#         },
#         "temperature": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kelvin",
#           "value": 313.15
#         }
#       },
#       "uncertainty": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "gram / milliliter",
#         "value": 0.0006748796455414605
#       },
#       "value": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "gram / milliliter",
#         "value": 0.7765098121669466
#       }
#     },
#     {
#       "@type": "openff.evaluator.properties.enthalpy.EnthalpyOfVaporization",
#       "gradients": [],
#       "id": "812af1a0210e412b9bb9e072004904ad",
#       "phase": 6,
#       "source": {
#         "@type": "openff.evaluator.datasets.provenance.CalculationSource",
#         "fidelity": "SimulationLayer",
#         "provenance": "{\"protocol_schemas\": [{\"id\": \"812af1a0210e412b9bb9e072004904ad|build_coordinates_liquid\", \"type\": \"BuildCoordinatesPackmol\", \"inputs\": {\".allow_merging\": true, \".max_molecules\": 256, \".count_exact_amount\": true, \".mass_density\": {\"value\": 0.95, \"unit\": \"gram / milliliter\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".box_aspect_ratio\": [1.0, 1.0, 1.0], \".substance\": {\"components\": [{\"smiles\": \"CCO\", \"role\": {\"value\": \"solv\", \"@type\": \"openff.evaluator.substances.components.Component.Role\"}, \"@type\": \"openff.evaluator.substances.components.Component\"}], \"amounts\": {\"CCO{solv}\": [{\"value\": 1.0, \"@type\": \"openff.evaluator.substances.amounts.MoleFraction\"}]}, \"@type\": \"openff.evaluator.substances.substances.Substance\"}, \".tolerance\": {\"value\": 2.0, \"unit\": \"angstrom\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".verbose_packmol\": false, \".retain_packmol_files\": false}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"812af1a0210e412b9bb9e072004904ad|energy_minimisation_liquid\", \"type\": \"OpenMMEnergyMinimisation\", \"inputs\": {\".allow_merging\": true, \".input_coordinate_file\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|build_coordinates_liquid.coordinate_file_path\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".tolerance\": {\"value\": 10.0, \"unit\": \"kilojoules_per_mole / nanometer\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".max_iterations\": 0, \".enable_pbc\": true}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"812af1a0210e412b9bb9e072004904ad|equilibration_simulation_liquid\", \"type\": \"OpenMMSimulation\", \"inputs\": {\".allow_merging\": true, \".steps_per_iteration\": 100000, \".total_number_of_iterations\": 1, \".output_frequency\": 5000, \".checkpoint_frequency\": 10, \".timestep\": {\"value\": 2.0, \"unit\": \"femtosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".thermodynamic_state\": {\"temperature\": {\"value\": 298.15, \"unit\": \"kelvin\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"pressure\": {\"value\": 1.0, \"unit\": \"standard_atmosphere\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \"@type\": \"openff.evaluator.thermodynamics.ThermodynamicState\"}, \".ensemble\": {\"value\": \"NPT\", \"@type\": \"openff.evaluator.thermodynamics.Ensemble\"}, \".thermostat_friction\": {\"value\": 1.0, \"unit\": \"1 / picosecond\", \"@type\": \"openff.evaluator.unit.Quantity\"}, \".input_coordinate_file\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|energy_minimisation_liquid.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".parameterized_system\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|assign_parameters_liquid.parameterized_system\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".enable_pbc\": true, \".allow_gpu_platforms\": true, \".high_precision\": false, \".gradient_parameters\": []}, \"@type\": \"openff.evaluator.workflow.schemas.ProtocolSchema\"}, {\"id\": \"812af1a0210e412b9bb9e072004904ad|decorrelate_trajectory_liquid\", \"type\": \"DecorrelateTrajectory\", \"inputs\": {\".allow_merging\": true, \".time_series_statistics\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|conditional_group/812af1a0210e412b9bb9e072004904ad|average_liquid_potential.time_series_statistics\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_coordinate_file\": {\"full_path\": \"812af1a0210e412b9bb9e072004904ad|conditional_group/812af1a0210e412b9bb9e072004904ad|production_simulation_liquid.output_coordinate_file\", \"@type\": \"openff.evaluator.workflow.utils.ProtocolPath\"}, \".input_trajectory_path\": {\"full_path\": \"8 ...
#       },
#       "substance": {
#         "@type": "openff.evaluator.substances.substances.Substance",
#         "amounts": {
#           "CCO{solv}": [
#             {
#               "@type": "openff.evaluator.substances.amounts.MoleFraction",
#               "value": 1.0
#             }
#           ]
#         },
#         "components": [
#           {
#             "@type": "openff.evaluator.substances.components.Component",
#             "role": {
#               "@type": "openff.evaluator.substances.components.Component.Role",
#               "value": "solv"
#             },
#             "smiles": "CCO"
#           }
#         ]
#       },
#       "thermodynamic_state": {
#         "@type": "openff.evaluator.thermodynamics.ThermodynamicState",
#         "pressure": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "standard_atmosphere",
#           "value": 1.0
#         },
#         "temperature": {
#           "@type": "openff.evaluator.unit.Quantity",
#           "unit": "kelvin",
#           "value": 298.15
#         }
#       },
#       "uncertainty": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "kilojoule / mole",
#         "value": 0.17373158044306686
#       },
#       "value": {
#         "@type": "openff.evaluator.unit.Quantity",
#         "unit": "kilojoule / mole",
#         "value": 39.84907644034555
#       }
#     }
#   ]
# }
