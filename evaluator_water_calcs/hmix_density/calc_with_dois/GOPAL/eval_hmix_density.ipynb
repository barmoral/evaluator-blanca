# %% [markdown]
# # Core Imports and Setup

# %%
import os
from pathlib import Path

import warnings
warnings.filterwarnings("ignore")

import logging
logging.getLogger("openff.toolkit").setLevel(logging.ERROR)

from openff import toolkit, evaluator

from openff.units import unit

# %% [markdown]
# # 0) Registering Custom ThermoML Properties

# %%
from openff.evaluator import properties
from openff.evaluator.datasets.thermoml import thermoml_property
from openff.evaluator.datasets import PhysicalProperty, PropertyPhase

@thermoml_property("Osmotic coefficient", supported_phases=PropertyPhase.Liquid)
class OsmoticCoefficient(PhysicalProperty):
    """A class representation of a osmotic coeff property"""

    @classmethod
    def default_unit(cls):
        return unit.dimensionless
    
...

custom_thermoml_props = [
    OsmoticCoefficient,
]

for custom_prop_cls in custom_thermoml_props:    
    setattr(properties, custom_prop_cls.__name__, custom_prop_cls)

# %% [markdown]
# # 1) - Loading ThermoML Data Sets

# %% [markdown]
# ## Extracting data from ThermoML

# %%
from openff.evaluator.datasets import PhysicalProperty, PropertyPhase, PhysicalPropertyDataSet
from openff.evaluator.datasets.thermoml import thermoml_property, ThermoMLDataSet

data_set_initial = PhysicalPropertyDataSet.from_json("training-properties-with-water.json")
data_set_initial.to_pandas()
# Out:
#        Id  Temperature (K)  Pressure (kPa)   Phase  N Components Component 1  \
# 0    6385           298.15           101.0  Liquid             2   CN1CCCCC1
# 1    6386           298.15           101.0  Liquid             2   CN1CCCCC1
# 2    6387           298.15           101.0  Liquid             2   CN1CCCCC1
# 3    6388           298.15           101.3  Liquid             2    CN(C)CCO
# 4    6389           298.15           101.3  Liquid             2    CN(C)CCO
# ..    ...              ...             ...     ...           ...         ...
# 118  7294           298.15           101.0  Liquid             2    C1COCCN1
# 119  7295           298.15           101.0  Liquid             2    C1COCCN1
# 120  7344           303.15           100.0  Liquid             2   NCCCNCCCN
# 121  7345           303.15           100.0  Liquid             2   NCCCNCCCN
# 122  7346           303.15           100.0  Liquid             2   NCCCNCCCN
#
#       Role 1  Mole Fraction 1 Exact Amount 1 Component 2   Role 2  \
# 0    Solvent          0.24520           None           O  Solvent
# 1    Solvent          0.50500           None           O  Solvent
# 2    Solvent          0.79070           None           O  Solvent
# 3    Solvent          0.26433           None           O  Solvent
# 4    Solvent          0.50770           None           O  Solvent
# ..       ...              ...            ...         ...      ...
# 118  Solvent          0.49110           None           O  Solvent
# 119  Solvent          0.71490           None           O  Solvent
# 120  Solvent          0.30050           None           O  Solvent
# 121  Solvent          0.49980           None           O  Solvent
# 122  Solvent          0.80150           None           O  Solvent
#
#      Mole Fraction 2 Exact Amount 2  Density Value (g / ml)  \
# 0            0.75480           None                0.903811
# 1            0.49500           None                0.858158
# 2            0.20930           None                0.826047
# 3            0.73567           None                0.959000
# 4            0.49230           None                0.923722
# ..               ...            ...                     ...
# 118          0.50890           None                     NaN
# 119          0.28510           None                     NaN
# 120          0.69950           None                     NaN
# 121          0.50020           None                     NaN
# 122          0.19850           None                     NaN
#
#      Density Uncertainty (g / ml)  EnthalpyOfMixing Value (kJ / mol)  \
# 0                             NaN                                NaN
# 1                             NaN                                NaN
# 2                             NaN                                NaN
# 3                             NaN                                NaN
# 4                             NaN                                NaN
# ..                            ...                                ...
# 118                           NaN                             -3.131
# 119                           NaN                             -1.753
# 120                           NaN                             -6.588
# 121                           NaN                             -5.544
# 122                           NaN                             -2.233
#
#      EnthalpyOfMixing Uncertainty (kJ / mol)                       Source
# 0                                        NaN  10.1016/j.fluid.2010.05.001
# 1                                        NaN  10.1016/j.fluid.2010.05.001
# 2                                        NaN  10.1016/j.fluid.2010.05.001
# 3                                        NaN     10.1021/acs.jced.6b00888
# 4                                        NaN    10.1016/j.jct.2004.11.016
# ..                                       ...                          ...
# 118                                      NaN    10.1016/j.jct.2015.06.006
# 119                                      NaN    10.1016/j.jct.2015.06.006
# 120                                      NaN    10.1016/j.jct.2015.04.030
# 121                                      NaN    10.1016/j.jct.2015.04.030
# 122                                      NaN    10.1016/j.jct.2015.04.030
#
# [123 rows x 18 columns]

# %%
print(len(data_set_initial))
print(data_set_initial.property_types)
print(data_set_initial.substances)
# Out:
# 123
# {'Density', 'EnthalpyOfMixing'}
# {<Substance CNCCO{solv}{x=0.501700}|O{solv}{x=0.498300}>, <Substance OCCNCCO{solv}{x=0.285600}|O{solv}{x=0.714400}>, <Substance CN1CCCCC1{solv}{x=0.505000}|O{solv}{x=0.495000}>, <Substance Cc1ccncc1{solv}{x=0.500000}|O{solv}{x=0.500000}>, <Substance OCCN(CCO)CCO{solv}{x=0.107783}|O{solv}{x=0.892217}>, <Substance CNCCO{solv}{x=0.198700}|O{solv}{x=0.801300}>, <Substance CN(C)CCCO{solv}{x=0.199800}|O{solv}{x=0.800200}>, <Substance CC(C)O{solv}{x=0.764357}|O{solv}{x=0.235643}>, <Substance CNCCO{solv}{x=0.800900}|O{solv}{x=0.199100}>, <Substance CN(C)CCCO{solv}{x=0.501900}|O{solv}{x=0.498100}>, <Substance CN(CCO)CCO{solv}{x=0.259300}|O{solv}{x=0.740700}>, <Substance OCCOCCO{solv}{x=0.500600}|O{solv}{x=0.499400}>, <Substance CCN(CC)CCO{solv}{x=0.193290}|O{solv}{x=0.806710}>, <Substance OCCN(CCO)CCO{solv}{x=0.490200}|O{solv}{x=0.509800}>, <Substance NCCNCCO{solv}{x=0.069900}|O{solv}{x=0.930100}>, <Substance C1CCNCC1{solv}{x=0.250000}|O{solv}{x=0.750000}>, <Substance CC(C)O{solv}{x=0.704000}|O{solv}{x=0.296000}>, <Substance CN(CCO)CCO{solv}{x=0.494100}|O{solv}{x=0.505900}>, <Substance CN(C)CCO{solv}{x=0.536500}|O{solv}{x=0.463500}>, <Substance CN1CCOCC1{solv}{x=0.253800}|O{solv}{x=0.746200}>, <Substance CNCCO{solv}{x=0.798800}|O{solv}{x=0.201200}>, <Substance CC(C)O{solv}{x=0.203100}|O{solv}{x=0.796900}>, <Substance CC(C)O{solv}{x=0.231278}|O{solv}{x=0.768722}>, <Substance C1COCCN1{solv}{x=0.498000}|O{solv}{x=0.502000}>, <Substance CCCOC(C)=O{solv}{x=0.831128}|O{solv}{x=0.168872}>, <Substance OCCN1CCOCC1{solv}{x=0.694900}|O{solv}{x=0.305100}>, <Substance CN1CCNCC1{solv}{x=0.792600}|O{solv}{x=0.207400}>, <Substance OCCN1CCOCC1{solv}{x=0.743900}|O{solv}{x=0.256100}>, <Substance NCCNCCO{solv}{x=0.400100}|O{solv}{x=0.599900}>, <Substance OCCN1CCOCC1{solv}{x=0.485200}|O{solv}{x=0.514800}>, <Substance NCCCO{solv}{x=0.498900}|O{solv}{x=0.501100}>, <Substance CN(C)CCO{solv}{x=0.205200}|O{solv}{x=0.794800}>, <Substance NCCCNCCCN{solv}{x=0.300500}|O{solv}{x=0.699500}>, <Substance C1COCCN1{solv}{x=0.491100}|O{solv}{x=0.508900}>, <Substance NCCCO{solv}{x=0.708044}|O{solv}{x=0.291956}>, <Substance NCCNCCN{solv}{x=0.501000}|O{solv}{x=0.499000}>, <Substance CC(C)O{solv}{x=0.498100}|O{solv}{x=0.501900}>, <Substance CN1CCNCC1{solv}{x=0.510900}|O{solv}{x=0.489100}>, <Substance OCCN1CCOCC1{solv}{x=0.246600}|O{solv}{x=0.753400}>, <Substance CN(CCO)CCO{solv}{x=0.257100}|O{solv}{x=0.742900}>, <Substance CN(C)CCO{solv}{x=0.799600}|O{solv}{x=0.200400}>, <Substance CCN(CC)CCO{solv}{x=0.700300}|O{solv}{x=0.299700}>, <Substance OCCN(CCO)CCO{solv}{x=0.206300}|O{solv}{x=0.793700}>, <Substance CN(C)CCO{solv}{x=0.507700}|O{solv}{x=0.492300}>, <Substance OCCNCCO{solv}{x=0.496900}|O{solv}{x=0.503100}>, <Substance CN(C)CCCO{solv}{x=0.501300}|O{solv}{x=0.498700}>, <Substance CNCCO{solv}{x=0.199200}|O{solv}{x=0.800800}>, <Substance OCCOCCO{solv}{x=0.301000}|O{solv}{x=0.699000}>, <Substance OC1=NCCC1{solv}{x=0.744800}|O{solv}{x=0.255200}>, <Substance CN1CCCCC1{solv}{x=0.790700}|O{solv}{x=0.209300}>, <Substance OC1=NCCC1{solv}{x=0.231900}|O{solv}{x=0.768100}>, <Substance OCCN1CCOCC1{solv}{x=0.300200}|O{solv}{x=0.699800}>, <Substance CN(CCO)CCO{solv}{x=0.484900}|O{solv}{x=0.515100}>, <Substance OCC(O)CO{solv}{x=0.490710}|O{solv}{x=0.509290}>, <Substance NCCCO{solv}{x=0.298200}|O{solv}{x=0.701800}>, <Substance OC1=NCCC1{solv}{x=0.246800}|O{solv}{x=0.753200}>, <Substance Cn1ccnc1{solv}{x=0.498200}|O{solv}{x=0.501800}>, <Substance Cn1ccnc1{solv}{x=0.779500}|O{solv}{x=0.220500}>, <Substance CN(C)CCO{solv}{x=0.765200}|O{solv}{x=0.234800}>, <Substance C1CCNCC1{solv}{x=0.750000}|O{solv}{x=0.250000}>, <Substance NCCCO{solv}{x=0.751500}|O{solv}{x=0.248500}>, <Substance OCCOCCO{solv}{x=0.790600}|O{solv}{x=0.209400}>, <Substance CN1CCNCC1{solv}{x=0.706500}|O{solv}{x=0.293500}>, <Substance CCN(CC)CCO{solv}{x=0.200800}|O{solv}{x=0.799200}>, <Substance CN(CCO)CCO{solv}{x=0.741100}|O{solv}{x=0.258900}>, <Substance OCC(O)CO{solv}{x=0.749360}|O{solv}{x=0.250640}>, <Substance OCCN(CCO)CCO{s ...

# %% [markdown]
# ## Filtering data set

# %%
from openff.evaluator.datasets.curation.components.filtering import FilterByPropertyTypes, FilterByPropertyTypesSchema
from openff.evaluator.datasets.curation.components.filtering import FilterByTemperature, FilterByTemperatureSchema
from openff.evaluator.datasets.curation.components.filtering import FilterByPressure, FilterByPressureSchema
from openff.evaluator.datasets.curation.components.filtering import FilterBySmiles, FilterBySmilesSchema

data_set_hmix_dens= FilterByPropertyTypes.apply(
    data_set_initial, FilterByPropertyTypesSchema(property_types=["EnthalpyOfMixing","Density"]))

print(len(data_set_hmix_dens))
# Out:
# 123

# %% [markdown]
# ### Inspecting and saving new properties

# %%
# save for future use
data_set_path = Path('filtered_dataset_hmix_dens.json')
data_set_hmix_dens.json(data_set_path, format=True)

# inspect new properties
pandas_data_set = data_set_hmix_dens.to_pandas()

# %%
pandas_data_set
# Out:
#        Id  Temperature (K)  Pressure (kPa)   Phase  N Components Component 1  \
# 0    6385           298.15           101.0  Liquid             2   CN1CCCCC1
# 1    6386           298.15           101.0  Liquid             2   CN1CCCCC1
# 2    6387           298.15           101.0  Liquid             2   CN1CCCCC1
# 3    6388           298.15           101.3  Liquid             2    CN(C)CCO
# 4    6389           298.15           101.3  Liquid             2    CN(C)CCO
# ..    ...              ...             ...     ...           ...         ...
# 118  7294           298.15           101.0  Liquid             2    C1COCCN1
# 119  7295           298.15           101.0  Liquid             2    C1COCCN1
# 120  7344           303.15           100.0  Liquid             2   NCCCNCCCN
# 121  7345           303.15           100.0  Liquid             2   NCCCNCCCN
# 122  7346           303.15           100.0  Liquid             2   NCCCNCCCN
#
#       Role 1  Mole Fraction 1 Exact Amount 1 Component 2   Role 2  \
# 0    Solvent          0.24520           None           O  Solvent
# 1    Solvent          0.50500           None           O  Solvent
# 2    Solvent          0.79070           None           O  Solvent
# 3    Solvent          0.26433           None           O  Solvent
# 4    Solvent          0.50770           None           O  Solvent
# ..       ...              ...            ...         ...      ...
# 118  Solvent          0.49110           None           O  Solvent
# 119  Solvent          0.71490           None           O  Solvent
# 120  Solvent          0.30050           None           O  Solvent
# 121  Solvent          0.49980           None           O  Solvent
# 122  Solvent          0.80150           None           O  Solvent
#
#      Mole Fraction 2 Exact Amount 2  Density Value (g / ml)  \
# 0            0.75480           None                0.903811
# 1            0.49500           None                0.858158
# 2            0.20930           None                0.826047
# 3            0.73567           None                0.959000
# 4            0.49230           None                0.923722
# ..               ...            ...                     ...
# 118          0.50890           None                     NaN
# 119          0.28510           None                     NaN
# 120          0.69950           None                     NaN
# 121          0.50020           None                     NaN
# 122          0.19850           None                     NaN
#
#      Density Uncertainty (g / ml)  EnthalpyOfMixing Value (kJ / mol)  \
# 0                             NaN                                NaN
# 1                             NaN                                NaN
# 2                             NaN                                NaN
# 3                             NaN                                NaN
# 4                             NaN                                NaN
# ..                            ...                                ...
# 118                           NaN                             -3.131
# 119                           NaN                             -1.753
# 120                           NaN                             -6.588
# 121                           NaN                             -5.544
# 122                           NaN                             -2.233
#
#      EnthalpyOfMixing Uncertainty (kJ / mol)                       Source
# 0                                        NaN  10.1016/j.fluid.2010.05.001
# 1                                        NaN  10.1016/j.fluid.2010.05.001
# 2                                        NaN  10.1016/j.fluid.2010.05.001
# 3                                        NaN     10.1021/acs.jced.6b00888
# 4                                        NaN    10.1016/j.jct.2004.11.016
# ..                                       ...                          ...
# 118                                      NaN    10.1016/j.jct.2015.06.006
# 119                                      NaN    10.1016/j.jct.2015.06.006
# 120                                      NaN    10.1016/j.jct.2015.04.030
# 121                                      NaN    10.1016/j.jct.2015.04.030
# 122                                      NaN    10.1016/j.jct.2015.04.030
#
# [123 rows x 18 columns]

# %% [markdown]
# # 2) Estimating Data Sets

# %% [markdown]
# ### Loading data set and FF parameters

# %%
# load data
data_set_path = Path('filtered_dataset_hmix_dens.json')
data_set = PhysicalPropertyDataSet.from_json(data_set_path)

# %%
from openff.toolkit.typing.engines.smirnoff import forcefield, ForceField
from openff.evaluator.forcefield import SmirnoffForceFieldSource

forcefield.get_available_force_fields()
# Out:
# ['ff14sb_0.0.4.offxml',
#  'ff14sb_off_impropers_0.0.2.offxml',
#  'ff14sb_0.0.2.offxml',
#  'ff14sb_0.0.1.offxml',
#  'ff14sb_off_impropers_0.0.1.offxml',
#  'ff14sb_off_impropers_0.0.3.offxml',
#  'ff14sb_off_impropers_0.0.4.offxml',
#  'ff14sb_0.0.3.offxml',
#  'smirnoff99Frosst-1.0.9.offxml',
#  'smirnoff99Frosst-1.0.7.offxml',
#  'smirnoff99Frosst-1.0.5.offxml',
#  'smirnoff99Frosst-1.0.0.offxml',
#  'smirnoff99Frosst-1.0.6.offxml',
#  'smirnoff99Frosst-1.0.2.offxml',
#  'smirnoff99Frosst-1.0.1.offxml',
#  'smirnoff99Frosst-1.0.8.offxml',
#  'smirnoff99Frosst-1.0.4.offxml',
#  'smirnoff99Frosst-1.0.3.offxml',
#  'smirnoff99Frosst-1.1.0.offxml',
#  'opc3-1.0.1.offxml',
#  'openff-2.0.0.offxml',
#  'openff_unconstrained-1.0.0-RC2.offxml',
#  'tip3p_fb-1.1.0.offxml',
#  'opc-1.0.2.offxml',
#  'opc-1.0.0.offxml',
#  'openff_unconstrained-2.1.0.offxml',
#  'openff_unconstrained-1.3.1.offxml',
#  'openff-1.3.0.offxml',
#  'openff-1.0.0-RC2.offxml',
#  'openff-1.0.1.offxml',
#  'opc3-1.0.0.offxml',
#  'tip4p_fb-1.0.1.offxml',
#  'spce-1.0.0.offxml',
#  'openff_unconstrained-1.0.0.offxml',
#  'tip3p_fb-1.0.0.offxml',
#  'openff-2.1.0.offxml',
#  'openff-2.0.0-rc.2.offxml',
#  'openff-2.1.0-rc.1.offxml',
#  'tip4p_fb-1.0.0.offxml',
#  'opc-1.0.1.offxml',
#  'tip3p-1.0.0.offxml',
#  'openff-1.1.0.offxml',
#  'tip4p_fb.offxml',
#  'openff-1.1.1.offxml',
#  'openff_unconstrained-2.1.0-rc.1.offxml',
#  'opc.offxml',
#  'spce.offxml',
#  'openff_unconstrained-1.1.0.offxml',
#  'openff_unconstrained-1.2.1.offxml',
#  'tip3p_fb-1.1.1.offxml',
#  'openff_unconstrained-2.0.0-rc.1.offxml',
#  'openff-1.0.0.offxml',
#  'openff_unconstrained-1.2.0.offxml',
#  'openff-2.0.0-rc.1.offxml',
#  'openff_unconstrained-1.0.0-RC1.offxml',
#  'tip4p_ew-1.0.0.offxml',
#  'openff_unconstrained-1.3.1-alpha.1.offxml',
#  'tip3p-1.0.1.offxml',
#  'openff-1.3.1.offxml',
#  'openff-1.0.0-RC1.offxml',
#  'tip5p-1.0.0.offxml',
#  'openff_unconstrained-1.1.1.offxml',
#  'openff_unconstrained-1.3.0.offxml',
#  'tip3p_fb.offxml',
#  'tip3p.offxml',
#  'openff-1.3.1-alpha.1.offxml',
#  'openff-1.2.0.offxml',
#  'tip5p.offxml',
#  'openff-1.2.1.offxml',
#  'openff_unconstrained-2.0.0.offxml',
#  'openff_unconstrained-2.0.0-rc.2.offxml',
#  'opc3.offxml',
#  'openff_unconstrained-1.0.1.offxml',
#  'tip4p_ew.offxml']

# %%
# # load FF
# ff_path = ForceField("openff-2.0.0.offxml", "opc3.offxml")
# force_field_source = SmirnoffForceFieldSource.from_object(ff_path)

# %%
from openff.interchange import Interchange
from openff.toolkit import Molecule, ForceField
from openff.units import unit

# gopal=ForceField('/home/bamo6610/Documents/evaluator-blanca/evaluator_water_calcs/hmix_density/calc_with_dois/GOPAL/gopal.offxml')

# %%
cwd=os.getcwd()
gopal_path="%s/gopal.offxml"%cwd
print(gopal_path)
# Out:
# /home/bamo6610/Documents/evaluator-blanca/evaluator_water_calcs/hmix_density/calc_with_dois/GOPAL/gopal.offxml

# %%
# load FF
# Evaluator wants to work with a JSON file for the force field
force_field = ForceField("openff-2.0.0.offxml",gopal_path)
with open("force-field.json", "w") as file:
    file.write(SmirnoffForceFieldSource.from_object(force_field).json())

force_field_source = SmirnoffForceFieldSource.from_json("force-field.json")

# %% [markdown]
# ### Defining Calculation Schemas

# %%
from openff.evaluator.properties import Density, EnthalpyOfMixing
from openff.evaluator.client import RequestOptions

# density_schema = Density.default_simulation_schema(n_molecules=256)
density_schema = Density.default_simulation_schema(n_molecules=256)
hmix_schema = EnthalpyOfMixing.default_simulation_schema(n_molecules=256)

# Create an options object which defines how the data set should be estimated.
estimation_options = RequestOptions()

# Specify that we only wish to use molecular simulation to estimate the data set.
estimation_options.calculation_layers = ["SimulationLayer"]

# Add our custom schemas, specifying that the should be used by the 'SimulationLayer'
estimation_options.add_schema("SimulationLayer", "Density", density_schema)
estimation_options.add_schema("SimulationLayer", "EnthalpyOfMixing", hmix_schema)

# %% [markdown]
# ## Launching a Server and Client

# %%
from openff.evaluator.backends import ComputeResources
from openff.evaluator.backends.dask import DaskLocalCluster
from openff.evaluator.server import EvaluatorServer
from openff.evaluator.client import EvaluatorClient
from openff.evaluator.client import ConnectionOptions

# define client to submit queries
port = 8118
evaluator_client = EvaluatorClient(ConnectionOptions(server_port=port))

# define available / preferred resources
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
resources = ComputeResources(
    number_of_threads=1,
    number_of_gpus=1,
    preferred_gpu_toolkit=ComputeResources.GPUToolkit.CUDA,
)

with DaskLocalCluster(number_of_workers=1, resources_per_worker=resources) as calculation_backend:
    # spin up server
    evaluator_server = EvaluatorServer(calculation_backend=calculation_backend, delete_working_files=False, port=port)
    evaluator_server.start(asynchronous=True)

    # estimate data set by submitting calculation schemas to newly-created server
    request, exception = evaluator_client.request_estimate(
        property_set=data_set,
        force_field_source=force_field_source,
        options=estimation_options,
    )

    # Wait for the results.
    results, exception = request.results(synchronous=True, polling_interval=30)
    assert exception is None
# Out:
# 2024-07-03 08:54:23,382 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/distributed/comm/inproc.py", line 215, in read
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# Fatal error in the main server loop
# Traceback (most recent call last):
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/server/server.py", line 656, in _handle_connections
#     self._handle_stream(connection, connection.getpeername())
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/server/server.py", line 637, in _handle_stream
#     self._handle_job_submission(connection, address, message_length)
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/server/server.py", line 576, in _handle_job_submission
#     self._launch_batch(batch)
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/server/server.py", line 502, in _launch_batch
#     current_layer.schedule_calculation(
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/layers/layers.py", line 389, in schedule_calculation
#     futures = cls._schedule_calculation(
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/layers/workflow.py", line 231, in _schedule_calculation
#     workflow_futures = workflow_graph.execute(layer_directory, calculation_backend)
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/workflow/workflow.py", line 941, in execute
#     protocol_outputs = self._protocol_graph.execute(
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/workflow/protocols.py", line 1036, in execute
#     protocol_outputs[protocol_id] = calculation_backend.submit_task(
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/backends/dask.py", line 832, in submit_task
#     return self._client.submit(
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/distributed/client.py", line 1961, in submit
#     futures = self._graph_to_futures(
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/distributed/client.py", line 3171, in _graph_to_futures
#     self._send_to_scheduler(
#   File "/home/bamo6610/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/distributed/client.py", line 1242, in _send_to_scheduler
#     raise Exception(
# Exception: Tried sending message after closing.  Status: closed
# Message: {'op': 'update-graph', 'graph_header': {'serializer': 'pickle', 'writeable': ()}, 'graph_frames': [b'\x80\x05\x95[\x08\x00\x00\x00\x00\x00\x00\x8c\x1edistributed.protocol.serialize\x94\x8c\x08ToPickle\x94\x93\x94)\x81\x94}\x94\x8c\x04data\x94\x8c\x13dask.highlevelgraph\x94\x8c\x0eHighLevelGraph\x94\x93\x94)\x81\x94}\x94(\x8c\x0cdependencies\x94}\x94\x8a\x06\xc0\x06P\xb6\x92\x7f\x8f\x94s\x8c\x10key_dependencies\x94}\x94\x8c\x06layers\x94}\x94\x8a\x06\xc0\x06P\xb6\x92\x7fh\x06\x8c\x11MaterializedLayer\x94\x93\x94)\x81\x94}\x94(\x8c\x0bannotations\x94N\x8c\x16collection_annotations\x94N\x8c\x07mapping\x94}\x94\x8c2_wrapped_function-46d83ff9c535cefb0c0a7885748406f4\x94(\x8c\ndask.utils\x94\x8c\x05apply\x94\x93\x94\x8c\x1eopenff.evaluator.backends.dask\x94\x8c"DaskLocalCluster._wrapped_function\x94\x93\x94]\x94(\x8c#openff.evaluator.workflow.protocols\x94\x8c\x1fProtocolGraph._execute_protocol\x94\x93\x94\x8cTworking-data/SimulationLayer/86ba5088106f438fb5715b67ba97a41d/6385_build_coordinates\x94X\x8a\x04\x00\x00{"id": "6385|build_coordinates", "type": "BuildCoordinatesPackmol", "inputs": {".allow_merging": true, ".max_molecules": 256, ".count_exact_amount": true, ".mass_density": {"value": 0.95, "unit": "gram / milliliter", "@type": "openff.evaluator.unit.Quantity"}, ".box_aspect_ratio": [1.0, 1.0, 1.0], ".substance": {"components": [{"smiles": "CN1CCCCC1", "role": {"value": "solv", "@type": "openff.evaluator.substances.components.Component.Role"}, "@type": "openff.evaluator.substances.components.Component"}, {"smiles": "O", "role": {"value": "solv", "@type": "openff.evaluator.substances.components.Component.Role"}, "@type": "openff.evaluator.substances.components.Component"}], "amounts": {"CN1CCCCC1{solv}": [{"value": 0.2452, "@type": "openff.evaluator.substances.amounts.MoleFraction"}], "O{solv}": [{"value": 0.7548, "@type": "openff.evaluator.substances.amounts.MoleFraction"}]}, "@type": "openff.evaluator.substances.substances.Substance"}, ".tolerance": {"value": 2.0, "unit": "angstrom", "@type": "openff.evaluator.unit.Quantity"}, ".verbose_packmol": false, ".retain_packmol_files": false}, "@type": "openff.evaluator.workflow.schemas.ProtocolSchema"}\x94\x88e}\x94(\x8c\x0fsafe_exceptions\x94\x88\x8c\x13available_resources\x94\x8c"openff.evaluator.backends.backends\x94\x8c\x10ComputeResources\x94\x93\x94)\x81\x94}\x94(\x8c\x11number_of_threads\x94K\x01\x8c\x0enumber_of_gpus\x94K\x01\x8c\x15preferred_gpu_toolkit\x94h*\x8c\x1bComputeResources.GPUToolkit\x94\x93\x94\x8c\x04CUDA\x94\x85\x94R\x94\x8c\x17preferred_gpu_precision\x94h*\x8c\x1dComputeResources.GPUPrecision\x94\x93\x94\x8c\x05mixed\x94\x85\x94R\x94\x8c\x13_gpu_device_indices\x94Nub\x8c\x0fgpu_assignments\x94}\x94\x8c+Worker-ab0b2866-e711-4f65-8344-c2b54f59e007\x94\x8c\x010\x94sut\x94subsubsb.'], 'keys': ['_wrapped_function-46d83ff9c535cefb0c0a7885748406f4'], 'internal_priority': {'_wrapped_function-46d83ff9c535cefb0c0a7885748406f4': 0}, 'submitting_task': None, 'fifo_timeout': '100 ms', 'actors': False, 'code': <ToPickle: ()>, 'annotations': <ToPickle: {}>}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 32
#      25 request, exception = evaluator_client.request_estimate(
#      26     property_set=data_set,
#      27     force_field_source=force_field_source,
#      28     options=estimation_options,
#      29 )
#      31 # Wait for the results.
# ---> 32 results, exception = request.results(synchronous=True, polling_interval=30)
#      33 assert exception is None
#
# File ~/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/client/client.py:161, in Request.results(self, synchronous, polling_interval)
#     158     self.validate()
#     159     self._client = EvaluatorClient(self.connection_options)
# --> 161 return self._client.retrieve_results(self.id, synchronous, polling_interval)
#
# File ~/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/client/client.py:753, in EvaluatorClient.retrieve_results(self, request_id, synchronous, polling_interval)
#     750 if polling_interval > 0:
#     751     sleep(polling_interval)
# --> 753 response, error = self._send_query_to_server(request_id)
#     755 if (
#     756     isinstance(response, RequestResult)
#     757     and len(response.queued_properties) > 0
#     758 ):
#     759     continue
#
# File ~/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/client/client.py:866, in EvaluatorClient._send_query_to_server(self, request_id)
#     863 connection.sendall(message_type + length + encoded_request_id)
#     865 # Wait for the server response.
# --> 866 header = recvall(connection, 4)
#     867 length = unpack_int(header)[0]
#     869 # Decode the response from the server. If everything
#     870 # went well, this should be the finished calculation.
#
# File ~/miniconda3/envs/evaluator-blanca/lib/python3.10/site-packages/openff/evaluator/utils/tcp.py:24, in recvall(sock, n)
#      22 data = bytearray()
#      23 while len(data) < n:
# ---> 24     packet = sock.recv(n - len(data))
#      25     if not packet:
#      26         return None
#
# KeyboardInterrupt:

# %%
print(len(results.queued_properties))

print(len(results.estimated_properties))

print(len(results.unsuccessful_properties))
print(len(results.exceptions))
# Out:
# 0
# 0
# 57
# 57

# %%
print(results.exceptions)
# Out:
# [WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None), WorkflowException(None)]

# %%
results.estimated_properties.json("estimated_dataset_hmix_dens.json", format=True)
# Out:
# '{\n  "@type": "openff.evaluator.datasets.datasets.PhysicalPropertyDataSet",\n  "properties": []\n}'

# %% [markdown]
# ## 3) Analysing Data Sets

# %% [markdown]
# ### Loading the Data Sets

# %%
experimental_data_set_path = "filtered_dataset_hmix.json"
estimated_data_set_path = "estimated_dataset_hmix.json"

experimental_data_set = PhysicalPropertyDataSet.from_json(experimental_data_set_path)
estimated_data_set = PhysicalPropertyDataSet.from_json(estimated_data_set_path)

# %%
experimental_data_set.to_pandas().head()
# Out:
#      Id  Temperature (K)  Pressure (kPa)   Phase  N Components Component 1  \
# 0  6391           298.15           101.0  Liquid             2    CN(C)CCO
# 1  6392           298.15           101.0  Liquid             2    CN(C)CCO
# 2  6393           298.15           101.0  Liquid             2    CN(C)CCO
# 3  6395           303.15           100.0  Liquid             2  CCN(CC)CCO
# 4  6396           303.15           100.0  Liquid             2  CCN(CC)CCO
#
#     Role 1  Mole Fraction 1 Exact Amount 1 Component 2   Role 2  \
# 0  Solvent           0.2052           None           O  Solvent
# 1  Solvent           0.5365           None           O  Solvent
# 2  Solvent           0.7996           None           O  Solvent
# 3  Solvent           0.2008           None           O  Solvent
# 4  Solvent           0.5002           None           O  Solvent
#
#    Mole Fraction 2 Exact Amount 2  EnthalpyOfMixing Value (kJ / mol)  \
# 0           0.7948           None                             -2.587
# 1           0.4635           None                             -2.575
# 2           0.2004           None                             -1.247
# 3           0.7992           None                             -2.185
# 4           0.4998           None                             -2.504
#
#   EnthalpyOfMixing Uncertainty (kJ / mol)                     Source
# 0                                    None  10.1016/j.jct.2007.03.010
# 1                                    None  10.1016/j.jct.2007.03.010
# 2                                    None  10.1016/j.jct.2007.03.010
# 3                                    None  10.1016/j.jct.2015.04.030
# 4                                    None  10.1016/j.jct.2015.04.030

# %%
estimated_data_set.to_pandas().head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
